# %% [markdown]
# # Treino

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ROOT_DIR = '/content/drive/My Drive/DeepLearning-UFG/Projeto/Potholev2'

# %%
# !ls -la "/content/drive/My Drive/DeepLearning-UFG/Projeto/Potholev2"
# Out:
# total 43
# -rw------- 1 root root  372 Jun 21 11:23 best_hyperparameters.yaml
# -rw------- 1 root root  313 Apr 17 15:04 dataColab.yaml
# -rw------- 1 root root  280 Apr 17 15:02 data.yaml
# drwx------ 2 root root 4096 Jun 21 12:52 Modelos
# drwx------ 2 root root 4096 Jun 25 14:09 Modelos_HP_500
# drwx------ 2 root root 4096 Jun 26 12:10 Modelos_HP_500_V2
# drwx------ 2 root root 4096 Jun 22 10:40 Modelos_Sem_Hyper
# -rw------- 1 root root 1187 Apr 17 15:02 README.roboflow.txt
# drwx------ 2 root root 4096 Apr 29 14:54 runs
# drwx------ 2 root root 4096 Apr 17 15:05 test
# drwx------ 2 root root 4096 Apr 17 15:05 train
# drwx------ 2 root root 4096 Apr 17 15:05 valid
# drwx------ 2 root root 4096 Jun 27 19:43 YOLOv9c
# drwx------ 2 root root 4096 Jun 27 12:27 YOLOv9t

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.2.45-py3-none-any.whl (793 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 793.6/793.6 kB 966.1 kB/s eta 0:00:00
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.25.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (3.7.1)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.8.0.76)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.11.4)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.3.0+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.18.0+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.66.4)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.0.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.13.1)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2024.6.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.15.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvjitlink_cu12-12.5.40-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, ultralytics-thop, ultralytics
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.40 nvidia-nvtx-cu12-12.1.105 ultralytics-8.2.45 ultralytics-thop-2.0.0

# %%
import os
import ultralytics
from ultralytics import YOLO

ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.45 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# Setup complete ✅ (12 CPUs, 83.5 GB RAM, 30.2/201.2 GB disk)

# %%
from ultralytics import YOLO

# Initialize the YOLO model
model = YOLO('yolov9s.yaml')

# Tune hyperparameters on COCO8 for 30 epochs
model.tune(data=os.path.join(ROOT_DIR,"dataColab.yaml"),
                  epochs=30, iterations=30,
                  optimizer='AdamW',
                  plots=True,
                  save=True,
                  val=True,
                  batch = -1,
                  device = 'cuda'
          )
# Out:
# Tuner: Initialized Tuner instance with 'tune_dir=runs/detect/tune'
# Tuner: 💡 Learn about tuning at https://docs.ultralytics.com/guides/hyperparameter-tuning
# Tuner: Starting iteration 1/30 with hyperparameters: {'lr0': 0.01, 'lrf': 0.01, 'momentum': 0.937, 'weight_decay': 0.0005, 'warmup_epochs': 3.0, 'warmup_momentum': 0.8, 'box': 7.5, 'cls': 0.5, 'dfl': 1.5, 'hsv_h': 0.015, 'hsv_s': 0.7, 'hsv_v': 0.4, 'degrees': 0.0, 'translate': 0.1, 'scale': 0.5, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.5, 'bgr': 0.0, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 1/30 iterations complete ✅ (475.96s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.34471 observed at iteration 1
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.70325, 'metrics/recall(B)': 0.50988, 'metrics/mAP50(B)': 0.59063, 'metrics/mAP50-95(B)': 0.31738, 'val/box_loss': 1.66083, 'val/cls_loss': 1.6031, 'val/dfl_loss': 1.78252, 'fitness': 0.34471}
# Tuner: Best fitness model is runs/detect/train
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.01
# momentum: 0.937
# weight_decay: 0.0005
# warmup_epochs: 3.0
# warmup_momentum: 0.8
# box: 7.5
# cls: 0.5
# dfl: 1.5
# hsv_h: 0.015
# hsv_s: 0.7
# hsv_v: 0.4
# degrees: 0.0
# translate: 0.1
# scale: 0.5
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.5
# bgr: 0.0
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 2/30 with hyperparameters: {'lr0': 0.0101, 'lrf': 0.01006, 'momentum': 0.93323, 'weight_decay': 0.00051, 'warmup_epochs': 3.0, 'warmup_momentum': 0.78033, 'box': 7.40844, 'cls': 0.50781, 'dfl': 1.5, 'hsv_h': 0.01447, 'hsv_s': 0.73847, 'hsv_v': 0.40558, 'degrees': 0.0, 'translate': 0.09763, 'scale': 0.50664, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.5, 'bgr': 0.0, 'mosaic': 0.9587, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 2/30 iterations complete ✅ (905.01s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.3801 observed at iteration 2
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.65202, 'metrics/recall(B)': 0.54545, 'metrics/mAP50(B)': 0.61326, 'metrics/mAP50-95(B)': 0.35419, 'val/box_loss': 1.54666, 'val/cls_loss': 1.49505, 'val/dfl_loss': 1.74626, 'fitness': 0.3801}
# Tuner: Best fitness model is runs/detect/train2
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.0101
# lrf: 0.01006
# momentum: 0.93323
# weight_decay: 0.00051
# warmup_epochs: 3.0
# warmup_momentum: 0.78033
# box: 7.40844
# cls: 0.50781
# dfl: 1.5
# hsv_h: 0.01447
# hsv_s: 0.73847
# hsv_v: 0.40558
# degrees: 0.0
# translate: 0.09763
# scale: 0.50664
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.5
# bgr: 0.0
# mosaic: 0.9587
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 3/30 with hyperparameters: {'lr0': 0.00775, 'lrf': 0.00862, 'momentum': 0.93323, 'weight_decay': 0.00049, 'warmup_epochs': 3.48374, 'warmup_momentum': 0.70215, 'box': 7.40844, 'cls': 0.44728, 'dfl': 1.25241, 'hsv_h': 0.01169, 'hsv_s': 0.54016, 'hsv_v': 0.48223, 'degrees': 0.0, 'translate': 0.08257, 'scale': 0.49626, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.44917, 'bgr': 0.0, 'mosaic': 0.9587, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 3/30 iterations complete ✅ (1332.87s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.38575 observed at iteration 3
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.74062, 'metrics/recall(B)': 0.51212, 'metrics/mAP50(B)': 0.62479, 'metrics/mAP50-95(B)': 0.35919, 'val/box_loss': 1.54814, 'val/cls_loss': 1.32186, 'val/dfl_loss': 1.51935, 'fitness': 0.38575}
# Tuner: Best fitness model is runs/detect/train3
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.00775
# lrf: 0.00862
# momentum: 0.93323
# weight_decay: 0.00049
# warmup_epochs: 3.48374
# warmup_momentum: 0.70215
# box: 7.40844
# cls: 0.44728
# dfl: 1.25241
# hsv_h: 0.01169
# hsv_s: 0.54016
# hsv_v: 0.48223
# degrees: 0.0
# translate: 0.08257
# scale: 0.49626
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.44917
# bgr: 0.0
# mosaic: 0.9587
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 4/30 with hyperparameters: {'lr0': 0.00719, 'lrf': 0.00989, 'momentum': 0.95545, 'weight_decay': 0.00045, 'warmup_epochs': 2.75645, 'warmup_momentum': 0.85278, 'box': 7.42502, 'cls': 0.4085, 'dfl': 1.36558, 'hsv_h': 0.01834, 'hsv_s': 0.70012, 'hsv_v': 0.42057, 'degrees': 0.0, 'translate': 0.08742, 'scale': 0.44311, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.52633, 'bgr': 0.0, 'mosaic': 0.89159, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 4/30 iterations complete ✅ (1762.45s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.39031 observed at iteration 4
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.7283, 'metrics/recall(B)': 0.51985, 'metrics/mAP50(B)': 0.63422, 'metrics/mAP50-95(B)': 0.36321, 'val/box_loss': 1.56207, 'val/cls_loss': 1.24226, 'val/dfl_loss': 1.62753, 'fitness': 0.39031}
# Tuner: Best fitness model is runs/detect/train4
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.00719
# lrf: 0.00989
# momentum: 0.95545
# weight_decay: 0.00045
# warmup_epochs: 2.75645
# warmup_momentum: 0.85278
# box: 7.42502
# cls: 0.4085
# dfl: 1.36558
# hsv_h: 0.01834
# hsv_s: 0.70012
# hsv_v: 0.42057
# degrees: 0.0
# translate: 0.08742
# scale: 0.44311
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.52633
# bgr: 0.0
# mosaic: 0.89159
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 5/30 with hyperparameters: {'lr0': 0.01009, 'lrf': 0.00997, 'momentum': 0.9295, 'weight_decay': 0.00051, 'warmup_epochs': 2.98347, 'warmup_momentum': 0.78033, 'box': 7.40844, 'cls': 0.50781, 'dfl': 1.4643, 'hsv_h': 0.01448, 'hsv_s': 0.74124, 'hsv_v': 0.40107, 'degrees': 0.0, 'translate': 0.09783, 'scale': 0.50912, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.4954, 'bgr': 0.0, 'mosaic': 0.96482, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 5/30 iterations complete ✅ (2191.18s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.39031 observed at iteration 4
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.7283, 'metrics/recall(B)': 0.51985, 'metrics/mAP50(B)': 0.63422, 'metrics/mAP50-95(B)': 0.36321, 'val/box_loss': 1.56207, 'val/cls_loss': 1.24226, 'val/dfl_loss': 1.62753, 'fitness': 0.39031}
# Tuner: Best fitness model is runs/detect/train4
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.00719
# lrf: 0.00989
# momentum: 0.95545
# weight_decay: 0.00045
# warmup_epochs: 2.75645
# warmup_momentum: 0.85278
# box: 7.42502
# cls: 0.4085
# dfl: 1.36558
# hsv_h: 0.01834
# hsv_s: 0.70012
# hsv_v: 0.42057
# degrees: 0.0
# translate: 0.08742
# scale: 0.44311
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.52633
# bgr: 0.0
# mosaic: 0.89159
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 6/30 with hyperparameters: {'lr0': 0.00973, 'lrf': 0.01006, 'momentum': 0.93323, 'weight_decay': 0.00055, 'warmup_epochs': 3.05902, 'warmup_momentum': 0.78033, 'box': 7.72626, 'cls': 0.52185, 'dfl': 1.51858, 'hsv_h': 0.01428, 'hsv_s': 0.7261, 'hsv_v': 0.42586, 'degrees': 0.0, 'translate': 0.09763, 'scale': 0.50584, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.5, 'bgr': 0.0, 'mosaic': 0.96337, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 6/30 iterations complete ✅ (2621.46s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.39031 observed at iteration 4
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.7283, 'metrics/recall(B)': 0.51985, 'metrics/mAP50(B)': 0.63422, 'metrics/mAP50-95(B)': 0.36321, 'val/box_loss': 1.56207, 'val/cls_loss': 1.24226, 'val/dfl_loss': 1.62753, 'fitness': 0.39031}
# Tuner: Best fitness model is runs/detect/train4
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.00719
# lrf: 0.00989
# momentum: 0.95545
# weight_decay: 0.00045
# warmup_epochs: 2.75645
# warmup_momentum: 0.85278
# box: 7.42502
# cls: 0.4085
# dfl: 1.36558
# hsv_h: 0.01834
# hsv_s: 0.70012
# hsv_v: 0.42057
# degrees: 0.0
# translate: 0.08742
# scale: 0.44311
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.52633
# bgr: 0.0
# mosaic: 0.89159
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 7/30 with hyperparameters: {'lr0': 0.0079, 'lrf': 0.00845, 'momentum': 0.93282, 'weight_decay': 0.00049, 'warmup_epochs': 3.61787, 'warmup_momentum': 0.70386, 'box': 7.55929, 'cls': 0.44694, 'dfl': 1.195, 'hsv_h': 0.01265, 'hsv_s': 0.58368, 'hsv_v': 0.49357, 'degrees': 0.0, 'translate': 0.0818, 'scale': 0.48688, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.46469, 'bgr': 0.0, 'mosaic': 0.93527, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 7/30 iterations complete ✅ (3051.97s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.41622 observed at iteration 7
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.68646, 'metrics/recall(B)': 0.57273, 'metrics/mAP50(B)': 0.66941, 'metrics/mAP50-95(B)': 0.38809, 'val/box_loss': 1.5265, 'val/cls_loss': 1.23719, 'val/dfl_loss': 1.38571, 'fitness': 0.41622}
# Tuner: Best fitness model is runs/detect/train7
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.0079
# lrf: 0.00845
# momentum: 0.93282
# weight_decay: 0.00049
# warmup_epochs: 3.61787
# warmup_momentum: 0.70386
# box: 7.55929
# cls: 0.44694
# dfl: 1.195
# hsv_h: 0.01265
# hsv_s: 0.58368
# hsv_v: 0.49357
# degrees: 0.0
# translate: 0.0818
# scale: 0.48688
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.46469
# bgr: 0.0
# mosaic: 0.93527
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 8/30 with hyperparameters: {'lr0': 0.01018, 'lrf': 0.01006, 'momentum': 0.9144, 'weight_decay': 0.00049, 'warmup_epochs': 3.09096, 'warmup_momentum': 0.78234, 'box': 7.31204, 'cls': 0.50338, 'dfl': 1.5, 'hsv_h': 0.0147, 'hsv_s': 0.71956, 'hsv_v': 0.40558, 'degrees': 0.0, 'translate': 0.09479, 'scale': 0.51264, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.50248, 'bgr': 0.0, 'mosaic': 0.9587, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 8/30 iterations complete ✅ (3482.42s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.41903 observed at iteration 8
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.66186, 'metrics/recall(B)': 0.57273, 'metrics/mAP50(B)': 0.64677, 'metrics/mAP50-95(B)': 0.39373, 'val/box_loss': 1.44829, 'val/cls_loss': 1.36348, 'val/dfl_loss': 1.66753, 'fitness': 0.41903}
# Tuner: Best fitness model is runs/detect/train8
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.01018
# lrf: 0.01006
# momentum: 0.9144
# weight_decay: 0.00049
# warmup_epochs: 3.09096
# warmup_momentum: 0.78234
# box: 7.31204
# cls: 0.50338
# dfl: 1.5
# hsv_h: 0.0147
# hsv_s: 0.71956
# hsv_v: 0.40558
# degrees: 0.0
# translate: 0.09479
# scale: 0.51264
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.50248
# bgr: 0.0
# mosaic: 0.9587
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 9/30 with hyperparameters: {'lr0': 0.0101, 'lrf': 0.01029, 'momentum': 0.92581, 'weight_decay': 0.00048, 'warmup_epochs': 2.9168, 'warmup_momentum': 0.78234, 'box': 6.7599, 'cls': 0.57847, 'dfl': 1.42839, 'hsv_h': 0.0147, 'hsv_s': 0.70318, 'hsv_v': 0.39635, 'degrees': 0.0, 'translate': 0.10024, 'scale': 0.54574, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.50248, 'bgr': 0.0, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 9/30 iterations complete ✅ (3911.49s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.41903 observed at iteration 8
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.66186, 'metrics/recall(B)': 0.57273, 'metrics/mAP50(B)': 0.64677, 'metrics/mAP50-95(B)': 0.39373, 'val/box_loss': 1.44829, 'val/cls_loss': 1.36348, 'val/dfl_loss': 1.66753, 'fitness': 0.41903}
# Tuner: Best fitness model is runs/detect/train8
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.01018
# lrf: 0.01006
# momentum: 0.9144
# weight_decay: 0.00049
# warmup_epochs: 3.09096
# warmup_momentum: 0.78234
# box: 7.31204
# cls: 0.50338
# dfl: 1.5
# hsv_h: 0.0147
# hsv_s: 0.71956
# hsv_v: 0.40558
# degrees: 0.0
# translate: 0.09479
# scale: 0.51264
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.50248
# bgr: 0.0
# mosaic: 0.9587
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 10/30 with hyperparameters: {'lr0': 0.00775, 'lrf': 0.00862, 'momentum': 0.95133, 'weight_decay': 0.00053, 'warmup_epochs': 3.19775, 'warmup_momentum': 0.83434, 'box': 7.05026, 'cls': 0.48421, 'dfl': 1.20614, 'hsv_h': 0.01169, 'hsv_s': 0.41134, 'hsv_v': 0.51407, 'degrees': 0.0, 'translate': 0.0866, 'scale': 0.56078, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.44917, 'bgr': 0.0, 'mosaic': 0.75643, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 10/30 iterations complete ✅ (4339.74s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.41903 observed at iteration 8
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.66186, 'metrics/recall(B)': 0.57273, 'metrics/mAP50(B)': 0.64677, 'metrics/mAP50-95(B)': 0.39373, 'val/box_loss': 1.44829, 'val/cls_loss': 1.36348, 'val/dfl_loss': 1.66753, 'fitness': 0.41903}
# Tuner: Best fitness model is runs/detect/train8
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.01018
# lrf: 0.01006
# momentum: 0.9144
# weight_decay: 0.00049
# warmup_epochs: 3.09096
# warmup_momentum: 0.78234
# box: 7.31204
# cls: 0.50338
# dfl: 1.5
# hsv_h: 0.0147
# hsv_s: 0.71956
# hsv_v: 0.40558
# degrees: 0.0
# translate: 0.09479
# scale: 0.51264
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.50248
# bgr: 0.0
# mosaic: 0.9587
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 11/30 with hyperparameters: {'lr0': 0.00819, 'lrf': 0.00919, 'momentum': 0.98, 'weight_decay': 0.00045, 'warmup_epochs': 1.34333, 'warmup_momentum': 0.87726, 'box': 7.20276, 'cls': 0.23817, 'dfl': 1.54547, 'hsv_h': 0.01557, 'hsv_s': 0.61448, 'hsv_v': 0.32656, 'degrees': 0.0, 'translate': 0.07348, 'scale': 0.35238, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.52633, 'bgr': 0.0, 'mosaic': 0.8355, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 11/30 iterations complete ✅ (4770.69s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.41903 observed at iteration 8
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.66186, 'metrics/recall(B)': 0.57273, 'metrics/mAP50(B)': 0.64677, 'metrics/mAP50-95(B)': 0.39373, 'val/box_loss': 1.44829, 'val/cls_loss': 1.36348, 'val/dfl_loss': 1.66753, 'fitness': 0.41903}
# Tuner: Best fitness model is runs/detect/train8
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.01018
# lrf: 0.01006
# momentum: 0.9144
# weight_decay: 0.00049
# warmup_epochs: 3.09096
# warmup_momentum: 0.78234
# box: 7.31204
# cls: 0.50338
# dfl: 1.5
# hsv_h: 0.0147
# hsv_s: 0.71956
# hsv_v: 0.40558
# degrees: 0.0
# translate: 0.09479
# scale: 0.51264
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.50248
# bgr: 0.0
# mosaic: 0.9587
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 12/30 with hyperparameters: {'lr0': 0.0079, 'lrf': 0.00842, 'momentum': 0.94156, 'weight_decay': 0.00049, 'warmup_epochs': 3.63874, 'warmup_momentum': 0.70386, 'box': 7.66094, 'cls': 0.42574, 'dfl': 1.195, 'hsv_h': 0.01265, 'hsv_s': 0.56559, 'hsv_v': 0.47176, 'degrees': 0.0, 'translate': 0.08571, 'scale': 0.47459, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.47857, 'bgr': 0.0, 'mosaic': 0.96656, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 12/30 iterations complete ✅ (5201.84s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.41903 observed at iteration 8
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.66186, 'metrics/recall(B)': 0.57273, 'metrics/mAP50(B)': 0.64677, 'metrics/mAP50-95(B)': 0.39373, 'val/box_loss': 1.44829, 'val/cls_loss': 1.36348, 'val/dfl_loss': 1.66753, 'fitness': 0.41903}
# Tuner: Best fitness model is runs/detect/train8
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.01018
# lrf: 0.01006
# momentum: 0.9144
# weight_decay: 0.00049
# warmup_epochs: 3.09096
# warmup_momentum: 0.78234
# box: 7.31204
# cls: 0.50338
# dfl: 1.5
# hsv_h: 0.0147
# hsv_s: 0.71956
# hsv_v: 0.40558
# degrees: 0.0
# translate: 0.09479
# scale: 0.51264
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.50248
# bgr: 0.0
# mosaic: 0.9587
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 13/30 with hyperparameters: {'lr0': 0.01041, 'lrf': 0.00823, 'momentum': 0.9144, 'weight_decay': 0.00049, 'warmup_epochs': 4.00758, 'warmup_momentum': 0.75317, 'box': 7.48342, 'cls': 0.53282, 'dfl': 1.63117, 'hsv_h': 0.01469, 'hsv_s': 0.83492, 'hsv_v': 0.40146, 'degrees': 0.0, 'translate': 0.10088, 'scale': 0.5003, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.50248, 'bgr': 0.0, 'mosaic': 0.88655, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 13/30 iterations complete ✅ (5631.87s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.41903 observed at iteration 8
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.66186, 'metrics/recall(B)': 0.57273, 'metrics/mAP50(B)': 0.64677, 'metrics/mAP50-95(B)': 0.39373, 'val/box_loss': 1.44829, 'val/cls_loss': 1.36348, 'val/dfl_loss': 1.66753, 'fitness': 0.41903}
# Tuner: Best fitness model is runs/detect/train8
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.01018
# lrf: 0.01006
# momentum: 0.9144
# weight_decay: 0.00049
# warmup_epochs: 3.09096
# warmup_momentum: 0.78234
# box: 7.31204
# cls: 0.50338
# dfl: 1.5
# hsv_h: 0.0147
# hsv_s: 0.71956
# hsv_v: 0.40558
# degrees: 0.0
# translate: 0.09479
# scale: 0.51264
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.50248
# bgr: 0.0
# mosaic: 0.9587
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 14/30 with hyperparameters: {'lr0': 0.01018, 'lrf': 0.00958, 'momentum': 0.86879, 'weight_decay': 0.00055, 'warmup_epochs': 3.72621, 'warmup_momentum': 0.7401, 'box': 7.6994, 'cls': 0.35805, 'dfl': 1.71505, 'hsv_h': 0.0147, 'hsv_s': 0.83589, 'hsv_v': 0.40558, 'degrees': 0.0, 'translate': 0.09368, 'scale': 0.34295, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.50248, 'bgr': 0.0, 'mosaic': 0.67208, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 14/30 iterations complete ✅ (6061.93s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.41903 observed at iteration 8
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.66186, 'metrics/recall(B)': 0.57273, 'metrics/mAP50(B)': 0.64677, 'metrics/mAP50-95(B)': 0.39373, 'val/box_loss': 1.44829, 'val/cls_loss': 1.36348, 'val/dfl_loss': 1.66753, 'fitness': 0.41903}
# Tuner: Best fitness model is runs/detect/train8
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.01018
# lrf: 0.01006
# momentum: 0.9144
# weight_decay: 0.00049
# warmup_epochs: 3.09096
# warmup_momentum: 0.78234
# box: 7.31204
# cls: 0.50338
# dfl: 1.5
# hsv_h: 0.0147
# hsv_s: 0.71956
# hsv_v: 0.40558
# degrees: 0.0
# translate: 0.09479
# scale: 0.51264
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.50248
# bgr: 0.0
# mosaic: 0.9587
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 15/30 with hyperparameters: {'lr0': 0.01092, 'lrf': 0.01132, 'momentum': 0.90217, 'weight_decay': 0.00049, 'warmup_epochs': 2.18755, 'warmup_momentum': 0.73993, 'box': 6.55296, 'cls': 0.41185, 'dfl': 1.72184, 'hsv_h': 0.01356, 'hsv_s': 0.85004, 'hsv_v': 0.54316, 'degrees': 0.0, 'translate': 0.12591, 'scale': 0.53782, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.50248, 'bgr': 0.0, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 15/30 iterations complete ✅ (6491.99s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.41903 observed at iteration 8
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.66186, 'metrics/recall(B)': 0.57273, 'metrics/mAP50(B)': 0.64677, 'metrics/mAP50-95(B)': 0.39373, 'val/box_loss': 1.44829, 'val/cls_loss': 1.36348, 'val/dfl_loss': 1.66753, 'fitness': 0.41903}
# Tuner: Best fitness model is runs/detect/train8
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.01018
# lrf: 0.01006
# momentum: 0.9144
# weight_decay: 0.00049
# warmup_epochs: 3.09096
# warmup_momentum: 0.78234
# box: 7.31204
# cls: 0.50338
# dfl: 1.5
# hsv_h: 0.0147
# hsv_s: 0.71956
# hsv_v: 0.40558
# degrees: 0.0
# translate: 0.09479
# scale: 0.51264
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.50248
# bgr: 0.0
# mosaic: 0.9587
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 16/30 with hyperparameters: {'lr0': 0.00719, 'lrf': 0.01022, 'momentum': 0.94103, 'weight_decay': 0.00045, 'warmup_epochs': 2.81423, 'warmup_momentum': 0.89398, 'box': 7.83591, 'cls': 0.41428, 'dfl': 1.36558, 'hsv_h': 0.01866, 'hsv_s': 0.67943, 'hsv_v': 0.44037, 'degrees': 0.0, 'translate': 0.08746, 'scale': 0.43111, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.53543, 'bgr': 0.0, 'mosaic': 0.94986, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 16/30 iterations complete ✅ (6922.80s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.41903 observed at iteration 8
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.66186, 'metrics/recall(B)': 0.57273, 'metrics/mAP50(B)': 0.64677, 'metrics/mAP50-95(B)': 0.39373, 'val/box_loss': 1.44829, 'val/cls_loss': 1.36348, 'val/dfl_loss': 1.66753, 'fitness': 0.41903}
# Tuner: Best fitness model is runs/detect/train8
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.01018
# lrf: 0.01006
# momentum: 0.9144
# weight_decay: 0.00049
# warmup_epochs: 3.09096
# warmup_momentum: 0.78234
# box: 7.31204
# cls: 0.50338
# dfl: 1.5
# hsv_h: 0.0147
# hsv_s: 0.71956
# hsv_v: 0.40558
# degrees: 0.0
# translate: 0.09479
# scale: 0.51264
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.50248
# bgr: 0.0
# mosaic: 0.9587
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 17/30 with hyperparameters: {'lr0': 0.01018, 'lrf': 0.01006, 'momentum': 0.96842, 'weight_decay': 0.00054, 'warmup_epochs': 3.36106, 'warmup_momentum': 0.95, 'box': 6.18108, 'cls': 0.38053, 'dfl': 1.91713, 'hsv_h': 0.01182, 'hsv_s': 0.79984, 'hsv_v': 0.40558, 'degrees': 0.0, 'translate': 0.111, 'scale': 0.51264, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.50749, 'bgr': 0.0, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 17/30 iterations complete ✅ (7352.97s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.41903 observed at iteration 8
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.66186, 'metrics/recall(B)': 0.57273, 'metrics/mAP50(B)': 0.64677, 'metrics/mAP50-95(B)': 0.39373, 'val/box_loss': 1.44829, 'val/cls_loss': 1.36348, 'val/dfl_loss': 1.66753, 'fitness': 0.41903}
# Tuner: Best fitness model is runs/detect/train8
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.01018
# lrf: 0.01006
# momentum: 0.9144
# weight_decay: 0.00049
# warmup_epochs: 3.09096
# warmup_momentum: 0.78234
# box: 7.31204
# cls: 0.50338
# dfl: 1.5
# hsv_h: 0.0147
# hsv_s: 0.71956
# hsv_v: 0.40558
# degrees: 0.0
# translate: 0.09479
# scale: 0.51264
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.50248
# bgr: 0.0
# mosaic: 0.9587
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 18/30 with hyperparameters: {'lr0': 0.00738, 'lrf': 0.00874, 'momentum': 0.87129, 'weight_decay': 0.00047, 'warmup_epochs': 3.54855, 'warmup_momentum': 0.81145, 'box': 7.73482, 'cls': 0.44141, 'dfl': 1.49841, 'hsv_h': 0.0134, 'hsv_s': 0.58368, 'hsv_v': 0.49357, 'degrees': 0.0, 'translate': 0.08627, 'scale': 0.37441, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.46469, 'bgr': 0.0, 'mosaic': 0.75486, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 18/30 iterations complete ✅ (7785.36s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.41903 observed at iteration 8
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.66186, 'metrics/recall(B)': 0.57273, 'metrics/mAP50(B)': 0.64677, 'metrics/mAP50-95(B)': 0.39373, 'val/box_loss': 1.44829, 'val/cls_loss': 1.36348, 'val/dfl_loss': 1.66753, 'fitness': 0.41903}
# Tuner: Best fitness model is runs/detect/train8
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.01018
# lrf: 0.01006
# momentum: 0.9144
# weight_decay: 0.00049
# warmup_epochs: 3.09096
# warmup_momentum: 0.78234
# box: 7.31204
# cls: 0.50338
# dfl: 1.5
# hsv_h: 0.0147
# hsv_s: 0.71956
# hsv_v: 0.40558
# degrees: 0.0
# translate: 0.09479
# scale: 0.51264
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.50248
# bgr: 0.0
# mosaic: 0.9587
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 19/30 with hyperparameters: {'lr0': 0.00725, 'lrf': 0.008, 'momentum': 0.86651, 'weight_decay': 0.00047, 'warmup_epochs': 4.1516, 'warmup_momentum': 0.87049, 'box': 7.73482, 'cls': 0.52549, 'dfl': 1.23418, 'hsv_h': 0.01334, 'hsv_s': 0.58368, 'hsv_v': 0.43761, 'degrees': 0.0, 'translate': 0.08627, 'scale': 0.39291, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.46469, 'bgr': 0.0, 'mosaic': 0.75486, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 19/30 iterations complete ✅ (8215.81s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.42748 observed at iteration 19
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.73035, 'metrics/recall(B)': 0.56667, 'metrics/mAP50(B)': 0.67349, 'metrics/mAP50-95(B)': 0.40015, 'val/box_loss': 1.52179, 'val/cls_loss': 1.41137, 'val/dfl_loss': 1.42331, 'fitness': 0.42748}
# Tuner: Best fitness model is runs/detect/train19
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.00725
# lrf: 0.008
# momentum: 0.86651
# weight_decay: 0.00047
# warmup_epochs: 4.1516
# warmup_momentum: 0.87049
# box: 7.73482
# cls: 0.52549
# dfl: 1.23418
# hsv_h: 0.01334
# hsv_s: 0.58368
# hsv_v: 0.43761
# degrees: 0.0
# translate: 0.08627
# scale: 0.39291
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.46469
# bgr: 0.0
# mosaic: 0.75486
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 20/30 with hyperparameters: {'lr0': 0.00725, 'lrf': 0.00724, 'momentum': 0.83015, 'weight_decay': 0.00047, 'warmup_epochs': 2.99594, 'warmup_momentum': 0.86883, 'box': 8.63959, 'cls': 0.53313, 'dfl': 1.28875, 'hsv_h': 0.01334, 'hsv_s': 0.71942, 'hsv_v': 0.40592, 'degrees': 0.0, 'translate': 0.08627, 'scale': 0.36049, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.37244, 'bgr': 0.0, 'mosaic': 0.75486, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 20/30 iterations complete ✅ (8646.75s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.42748 observed at iteration 19
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.73035, 'metrics/recall(B)': 0.56667, 'metrics/mAP50(B)': 0.67349, 'metrics/mAP50-95(B)': 0.40015, 'val/box_loss': 1.52179, 'val/cls_loss': 1.41137, 'val/dfl_loss': 1.42331, 'fitness': 0.42748}
# Tuner: Best fitness model is runs/detect/train19
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.00725
# lrf: 0.008
# momentum: 0.86651
# weight_decay: 0.00047
# warmup_epochs: 4.1516
# warmup_momentum: 0.87049
# box: 7.73482
# cls: 0.52549
# dfl: 1.23418
# hsv_h: 0.01334
# hsv_s: 0.58368
# hsv_v: 0.43761
# degrees: 0.0
# translate: 0.08627
# scale: 0.39291
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.46469
# bgr: 0.0
# mosaic: 0.75486
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 21/30 with hyperparameters: {'lr0': 0.0072, 'lrf': 0.00799, 'momentum': 0.86614, 'weight_decay': 0.00047, 'warmup_epochs': 4.15033, 'warmup_momentum': 0.86776, 'box': 7.73482, 'cls': 0.52478, 'dfl': 1.23883, 'hsv_h': 0.0133, 'hsv_s': 0.58147, 'hsv_v': 0.43611, 'degrees': 0.0, 'translate': 0.08608, 'scale': 0.39291, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.46568, 'bgr': 0.0, 'mosaic': 0.75486, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 21/30 iterations complete ✅ (9078.35s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.42748 observed at iteration 19
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.73035, 'metrics/recall(B)': 0.56667, 'metrics/mAP50(B)': 0.67349, 'metrics/mAP50-95(B)': 0.40015, 'val/box_loss': 1.52179, 'val/cls_loss': 1.41137, 'val/dfl_loss': 1.42331, 'fitness': 0.42748}
# Tuner: Best fitness model is runs/detect/train19
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.00725
# lrf: 0.008
# momentum: 0.86651
# weight_decay: 0.00047
# warmup_epochs: 4.1516
# warmup_momentum: 0.87049
# box: 7.73482
# cls: 0.52549
# dfl: 1.23418
# hsv_h: 0.01334
# hsv_s: 0.58368
# hsv_v: 0.43761
# degrees: 0.0
# translate: 0.08627
# scale: 0.39291
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.46469
# bgr: 0.0
# mosaic: 0.75486
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 22/30 with hyperparameters: {'lr0': 0.00747, 'lrf': 0.00822, 'momentum': 0.86614, 'weight_decay': 0.00032, 'warmup_epochs': 4.15033, 'warmup_momentum': 0.88554, 'box': 5.00239, 'cls': 0.58052, 'dfl': 1.23883, 'hsv_h': 0.01755, 'hsv_s': 0.58147, 'hsv_v': 0.39702, 'degrees': 0.0, 'translate': 0.10164, 'scale': 0.36058, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.3467, 'bgr': 0.0, 'mosaic': 0.74873, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 22/30 iterations complete ✅ (9510.61s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.43342 observed at iteration 22
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.74393, 'metrics/recall(B)': 0.57273, 'metrics/mAP50(B)': 0.68973, 'metrics/mAP50-95(B)': 0.40494, 'val/box_loss': 0.97815, 'val/cls_loss': 1.51786, 'val/dfl_loss': 1.39328, 'fitness': 0.43342}
# Tuner: Best fitness model is runs/detect/train22
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.00747
# lrf: 0.00822
# momentum: 0.86614
# weight_decay: 0.00032
# warmup_epochs: 4.15033
# warmup_momentum: 0.88554
# box: 5.00239
# cls: 0.58052
# dfl: 1.23883
# hsv_h: 0.01755
# hsv_s: 0.58147
# hsv_v: 0.39702
# degrees: 0.0
# translate: 0.10164
# scale: 0.36058
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.3467
# bgr: 0.0
# mosaic: 0.74873
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 23/30 with hyperparameters: {'lr0': 0.00807, 'lrf': 0.00822, 'momentum': 0.86633, 'weight_decay': 0.00037, 'warmup_epochs': 4.15033, 'warmup_momentum': 0.84951, 'box': 5.2731, 'cls': 0.69585, 'dfl': 1.4272, 'hsv_h': 0.01999, 'hsv_s': 0.58147, 'hsv_v': 0.35759, 'degrees': 0.0, 'translate': 0.08435, 'scale': 0.29032, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.3467, 'bgr': 0.0, 'mosaic': 0.74873, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 23/30 iterations complete ✅ (9943.04s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.43342 observed at iteration 22
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.74393, 'metrics/recall(B)': 0.57273, 'metrics/mAP50(B)': 0.68973, 'metrics/mAP50-95(B)': 0.40494, 'val/box_loss': 0.97815, 'val/cls_loss': 1.51786, 'val/dfl_loss': 1.39328, 'fitness': 0.43342}
# Tuner: Best fitness model is runs/detect/train22
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.00747
# lrf: 0.00822
# momentum: 0.86614
# weight_decay: 0.00032
# warmup_epochs: 4.15033
# warmup_momentum: 0.88554
# box: 5.00239
# cls: 0.58052
# dfl: 1.23883
# hsv_h: 0.01755
# hsv_s: 0.58147
# hsv_v: 0.39702
# degrees: 0.0
# translate: 0.10164
# scale: 0.36058
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.3467
# bgr: 0.0
# mosaic: 0.74873
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 24/30 with hyperparameters: {'lr0': 0.00775, 'lrf': 0.00962, 'momentum': 0.86905, 'weight_decay': 0.00048, 'warmup_epochs': 3.29699, 'warmup_momentum': 0.95, 'box': 7.32711, 'cls': 0.50666, 'dfl': 1.12551, 'hsv_h': 0.00952, 'hsv_s': 0.59285, 'hsv_v': 0.43761, 'degrees': 0.0, 'translate': 0.09985, 'scale': 0.24441, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.54152, 'bgr': 0.0, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 24/30 iterations complete ✅ (10373.88s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.43342 observed at iteration 22
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.74393, 'metrics/recall(B)': 0.57273, 'metrics/mAP50(B)': 0.68973, 'metrics/mAP50-95(B)': 0.40494, 'val/box_loss': 0.97815, 'val/cls_loss': 1.51786, 'val/dfl_loss': 1.39328, 'fitness': 0.43342}
# Tuner: Best fitness model is runs/detect/train22
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.00747
# lrf: 0.00822
# momentum: 0.86614
# weight_decay: 0.00032
# warmup_epochs: 4.15033
# warmup_momentum: 0.88554
# box: 5.00239
# cls: 0.58052
# dfl: 1.23883
# hsv_h: 0.01755
# hsv_s: 0.58147
# hsv_v: 0.39702
# degrees: 0.0
# translate: 0.10164
# scale: 0.36058
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.3467
# bgr: 0.0
# mosaic: 0.74873
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 25/30 with hyperparameters: {'lr0': 0.00785, 'lrf': 0.00662, 'momentum': 0.86614, 'weight_decay': 0.00047, 'warmup_epochs': 4.87245, 'warmup_momentum': 0.88554, 'box': 5.00239, 'cls': 0.58052, 'dfl': 1.00528, 'hsv_h': 0.02213, 'hsv_s': 0.59795, 'hsv_v': 0.37084, 'degrees': 0.0, 'translate': 0.09786, 'scale': 0.46999, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.23701, 'bgr': 0.0, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 25/30 iterations complete ✅ (10805.09s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.43342 observed at iteration 22
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.74393, 'metrics/recall(B)': 0.57273, 'metrics/mAP50(B)': 0.68973, 'metrics/mAP50-95(B)': 0.40494, 'val/box_loss': 0.97815, 'val/cls_loss': 1.51786, 'val/dfl_loss': 1.39328, 'fitness': 0.43342}
# Tuner: Best fitness model is runs/detect/train22
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.00747
# lrf: 0.00822
# momentum: 0.86614
# weight_decay: 0.00032
# warmup_epochs: 4.15033
# warmup_momentum: 0.88554
# box: 5.00239
# cls: 0.58052
# dfl: 1.23883
# hsv_h: 0.01755
# hsv_s: 0.58147
# hsv_v: 0.39702
# degrees: 0.0
# translate: 0.10164
# scale: 0.36058
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.3467
# bgr: 0.0
# mosaic: 0.74873
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 26/30 with hyperparameters: {'lr0': 0.00747, 'lrf': 0.00826, 'momentum': 0.86726, 'weight_decay': 0.00032, 'warmup_epochs': 4.34746, 'warmup_momentum': 0.90019, 'box': 5.00239, 'cls': 0.56187, 'dfl': 1.23949, 'hsv_h': 0.01755, 'hsv_s': 0.59858, 'hsv_v': 0.39702, 'degrees': 0.0, 'translate': 0.10164, 'scale': 0.36058, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.35165, 'bgr': 0.0, 'mosaic': 0.74873, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 26/30 iterations complete ✅ (11236.53s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.43342 observed at iteration 22
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.74393, 'metrics/recall(B)': 0.57273, 'metrics/mAP50(B)': 0.68973, 'metrics/mAP50-95(B)': 0.40494, 'val/box_loss': 0.97815, 'val/cls_loss': 1.51786, 'val/dfl_loss': 1.39328, 'fitness': 0.43342}
# Tuner: Best fitness model is runs/detect/train22
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.00747
# lrf: 0.00822
# momentum: 0.86614
# weight_decay: 0.00032
# warmup_epochs: 4.15033
# warmup_momentum: 0.88554
# box: 5.00239
# cls: 0.58052
# dfl: 1.23883
# hsv_h: 0.01755
# hsv_s: 0.58147
# hsv_v: 0.39702
# degrees: 0.0
# translate: 0.10164
# scale: 0.36058
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.3467
# bgr: 0.0
# mosaic: 0.74873
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 27/30 with hyperparameters: {'lr0': 0.00747, 'lrf': 0.00668, 'momentum': 0.86614, 'weight_decay': 0.0003, 'warmup_epochs': 4.30167, 'warmup_momentum': 0.88554, 'box': 4.62294, 'cls': 0.64922, 'dfl': 1.37425, 'hsv_h': 0.01755, 'hsv_s': 0.56409, 'hsv_v': 0.39702, 'degrees': 0.0, 'translate': 0.09345, 'scale': 0.36058, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.3467, 'bgr': 0.0, 'mosaic': 0.79887, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 27/30 iterations complete ✅ (11667.30s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.43342 observed at iteration 22
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.74393, 'metrics/recall(B)': 0.57273, 'metrics/mAP50(B)': 0.68973, 'metrics/mAP50-95(B)': 0.40494, 'val/box_loss': 0.97815, 'val/cls_loss': 1.51786, 'val/dfl_loss': 1.39328, 'fitness': 0.43342}
# Tuner: Best fitness model is runs/detect/train22
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.00747
# lrf: 0.00822
# momentum: 0.86614
# weight_decay: 0.00032
# warmup_epochs: 4.15033
# warmup_momentum: 0.88554
# box: 5.00239
# cls: 0.58052
# dfl: 1.23883
# hsv_h: 0.01755
# hsv_s: 0.58147
# hsv_v: 0.39702
# degrees: 0.0
# translate: 0.10164
# scale: 0.36058
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.3467
# bgr: 0.0
# mosaic: 0.74873
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 28/30 with hyperparameters: {'lr0': 0.00725, 'lrf': 0.008, 'momentum': 0.86651, 'weight_decay': 0.0005, 'warmup_epochs': 3.46929, 'warmup_momentum': 0.87049, 'box': 9.68371, 'cls': 0.61034, 'dfl': 1.26457, 'hsv_h': 0.01313, 'hsv_s': 0.6789, 'hsv_v': 0.50135, 'degrees': 0.0, 'translate': 0.08519, 'scale': 0.438, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.35005, 'bgr': 0.0, 'mosaic': 0.65883, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 28/30 iterations complete ✅ (12098.32s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.43342 observed at iteration 22
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.74393, 'metrics/recall(B)': 0.57273, 'metrics/mAP50(B)': 0.68973, 'metrics/mAP50-95(B)': 0.40494, 'val/box_loss': 0.97815, 'val/cls_loss': 1.51786, 'val/dfl_loss': 1.39328, 'fitness': 0.43342}
# Tuner: Best fitness model is runs/detect/train22
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.00747
# lrf: 0.00822
# momentum: 0.86614
# weight_decay: 0.00032
# warmup_epochs: 4.15033
# warmup_momentum: 0.88554
# box: 5.00239
# cls: 0.58052
# dfl: 1.23883
# hsv_h: 0.01755
# hsv_s: 0.58147
# hsv_v: 0.39702
# degrees: 0.0
# translate: 0.10164
# scale: 0.36058
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.3467
# bgr: 0.0
# mosaic: 0.74873
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 29/30 with hyperparameters: {'lr0': 0.0074, 'lrf': 0.00818, 'momentum': 0.86614, 'weight_decay': 0.00033, 'warmup_epochs': 4.15033, 'warmup_momentum': 0.92142, 'box': 4.90686, 'cls': 0.58052, 'dfl': 1.28107, 'hsv_h': 0.01549, 'hsv_s': 0.59518, 'hsv_v': 0.43705, 'degrees': 0.0, 'translate': 0.09981, 'scale': 0.39039, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.33934, 'bgr': 0.0, 'mosaic': 0.81826, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 29/30 iterations complete ✅ (12527.71s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.43342 observed at iteration 22
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.74393, 'metrics/recall(B)': 0.57273, 'metrics/mAP50(B)': 0.68973, 'metrics/mAP50-95(B)': 0.40494, 'val/box_loss': 0.97815, 'val/cls_loss': 1.51786, 'val/dfl_loss': 1.39328, 'fitness': 0.43342}
# Tuner: Best fitness model is runs/detect/train22
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.00747
# lrf: 0.00822
# momentum: 0.86614
# weight_decay: 0.00032
# warmup_epochs: 4.15033
# warmup_momentum: 0.88554
# box: 5.00239
# cls: 0.58052
# dfl: 1.23883
# hsv_h: 0.01755
# hsv_s: 0.58147
# hsv_v: 0.39702
# degrees: 0.0
# translate: 0.10164
# scale: 0.36058
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.3467
# bgr: 0.0
# mosaic: 0.74873
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 30/30 with hyperparameters: {'lr0': 0.00725, 'lrf': 0.008, 'momentum': 0.85075, 'weight_decay': 0.00048, 'warmup_epochs': 3.56748, 'warmup_momentum': 0.85302, 'box': 8.39584, 'cls': 0.52549, 'dfl': 1.54509, 'hsv_h': 0.01305, 'hsv_s': 0.57421, 'hsv_v': 0.51152, 'degrees': 0.0, 'translate': 0.07798, 'scale': 0.499, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.54802, 'bgr': 0.0, 'mosaic': 0.92393, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 30/30 iterations complete ✅ (12957.31s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.43342 observed at iteration 22
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.74393, 'metrics/recall(B)': 0.57273, 'metrics/mAP50(B)': 0.68973, 'metrics/mAP50-95(B)': 0.40494, 'val/box_loss': 0.97815, 'val/cls_loss': 1.51786, 'val/dfl_loss': 1.39328, 'fitness': 0.43342}
# Tuner: Best fitness model is runs/detect/train22
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.00747
# lrf: 0.00822
# momentum: 0.86614
# weight_decay: 0.00032
# warmup_epochs: 4.15033
# warmup_momentum: 0.88554
# box: 5.00239
# cls: 0.58052
# dfl: 1.23883
# hsv_h: 0.01755
# hsv_s: 0.58147
# hsv_v: 0.39702
# degrees: 0.0
# translate: 0.10164
# scale: 0.36058
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.3467
# bgr: 0.0
# mosaic: 0.74873
# mixup: 0.0
# copy_paste: 0.0
