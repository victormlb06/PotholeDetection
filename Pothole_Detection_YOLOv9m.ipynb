# %% [markdown]
# # Treino

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
ROOT_DIR = '/content/drive/My Drive/DeepLearning-UFG/Projeto/Potholev2'

# %%
# !ls -la "/content/drive/My Drive/DeepLearning-UFG/Projeto/Potholev2"
# Out:
# total 51
# -rw------- 1 root root  372 Jun 21 11:23 best_hyperparameters.yaml
# -rw------- 1 root root  313 Apr 17 15:04 dataColab.yaml
# -rw------- 1 root root  280 Apr 17 15:02 data.yaml
# drwx------ 2 root root 4096 Jun 21 12:52 Modelos
# drwx------ 2 root root 4096 Jun 25 14:09 Modelos_HP_500
# drwx------ 2 root root 4096 Jun 26 12:10 Modelos_HP_500_V2
# drwx------ 2 root root 4096 Jun 22 10:40 Modelos_Sem_Hyper
# -rw------- 1 root root 1187 Apr 17 15:02 README.roboflow.txt
# drwx------ 2 root root 4096 Apr 29 14:54 runs
# drwx------ 2 root root 4096 Apr 17 15:05 test
# drwx------ 2 root root 4096 Apr 17 15:05 train
# drwx------ 2 root root 4096 Apr 17 15:05 valid
# drwx------ 2 root root 4096 Jun 27 19:43 YOLOv9c
# drwx------ 2 root root 4096 Jun 28 17:35 YOLOv9m
# drwx------ 2 root root 4096 Jun 28 10:36 YOLOv9s
# drwx------ 2 root root 4096 Jun 27 12:27 YOLOv9t

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 793.7/793.7 kB 16.5 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
import os
import ultralytics
from ultralytics import YOLO

ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.48 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# Setup complete ✅ (12 CPUs, 83.5 GB RAM, 30.2/201.2 GB disk)

# %%
hyp = {
    'lr0': 0.00589,
    'lrf': 0.00799,
    'momentum': 0.85719,
    'weight_decay': 0.00056,
    'warmup_epochs': 2.44958,
    'warmup_momentum': 0.77388,
    'box': 12.51129,
    'cls': 0.48018,
    'dfl': 2.06179,
    'hsv_h': 0.01408,
    'hsv_s': 0.84602,
    'hsv_v': 0.53276,
    'degrees': 0.0,
    'translate': 0.06148,
    'scale': 0.61314,
    'shear': 0.0,
    'perspective': 0.0,
    'flipud': 0.0,
    'fliplr': 0.63517,
    'bgr': 0.0,
    'mosaic': 0.93926,
    'mixup': 0.0,
    'copy_paste': 0.0
}

# %%
import yaml

with open('hyp.yaml', 'w') as f:
    yaml.dump(hyp, f)

# %%
cfg = 'hyp.yaml'
with open(cfg, "r") as stream:
  try:
    cfg_args = yaml.safe_load(stream)
  except yaml.YAMLError as exc:
    print(exc)

# %%
MODEL_DIR = '/content/drive/MyDrive/DeepLearning-UFG/Projeto/Potholev2/YOLOv9m/VersaoFinal/weights/last.pt'

# %%
#model = YOLO('yolov9m.yaml')

model = YOLO(MODEL_DIR)

results = model.train(data=os.path.join(
            ROOT_DIR,"dataColab.yaml"),
            device = "cuda",
            epochs = 500,
            optimizer='AdamW',
            **cfg_args,
            save=True,
            save_period = 50,
            project = ROOT_DIR+"/YOLOv9m/",
            name = "VersaoFinal",
            batch = -1,
            resume =  True
            )
# Out:
# Ultralytics YOLOv8.2.48 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %%
model.info()
# Out:
# YOLOv9m summary: 603 layers, 20159043 parameters, 0 gradients, 77.5 GFLOPs
# (603, 20159043, 0, 77.5479936)

# %%
import locale
print(locale.getpreferredencoding())
# Out:
# ANSI_X3.4-1968

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
# !scp -r /content/runs '/content/drive/My Drive/DeepLearning-UFG/Projeto/PotholevFV'
# Out:
# cp: cannot stat '/content/runs': No such file or directory

# %% [markdown]
# # Teste

# %%
import cv2

# %%
VIDEO_PATH = '/content/drive/My Drive/DeepLearning-UFG/Projeto/Potholev1/Video/Reportagem.mp4'
VIDEO_OUT = '/content/drive/My Drive/DeepLearning-UFG/Projeto/Potholev1/Video/'

# %%
cap = cv2.VideoCapture(VIDEO_PATH)

# %%
ret, frame = cap.read()

# %%
H, W, _ = frame.shape

# %%
out = cv2.VideoWriter(VIDEO_OUT, cv2.VideoWriter_fourcc(*'MP4V'),int(cap.get(cv2.CAP_PROP_FPS)),(W,H))

# %%
model = YOLO("/content/drive/MyDrive/DeepLearning-UFG/Projeto/Potholev2Modelos/Final_PD3/weights/best.pt")

# %%
threshold = 0.5

# %%
while ret:

    results = model(frame)[0]

    for result in results.boxes.data.tolist():
        x1, y1, x2, y2, score, class_id = result

        if score > threshold:
            cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 4)
            cv2.putText(frame, results.names[int(class_id)].upper(), (int(x1), int(y1 - 10)),
                        cv2.FONT_HERSHEY_SIMPLEX, 1.3, (0, 255, 0), 3, cv2.LINE_AA)

    out.write(frame)
    ret, frame = cap.read()

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# 0: 384x640 (no detections), 17.5ms
# Speed: 1.9ms preprocess, 17.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.6ms
# Speed: 2.0ms preprocess, 18.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.9ms
# Speed: 2.2ms preprocess, 17.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.8ms
# Speed: 2.0ms preprocess, 18.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.2ms
# Speed: 2.0ms preprocess, 18.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.7ms
# Speed: 2.2ms preprocess, 18.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.7ms
# ...
