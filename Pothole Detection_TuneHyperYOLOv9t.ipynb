# %% [markdown]
# # Treino

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ROOT_DIR = '/content/drive/My Drive/DeepLearning-UFG/Projeto/Potholev2'

# %%
# !ls -la "/content/drive/My Drive/DeepLearning-UFG/Projeto/Potholev2"
# Out:
# total 27
# -rw------- 1 root root  372 Jun 21 11:23 best_hyperparameters.yaml
# -rw------- 1 root root  313 Apr 17 15:04 dataColab.yaml
# -rw------- 1 root root  280 Apr 17 15:02 data.yaml
# drwx------ 2 root root 4096 Jun 21 12:52 Modelos
# drwx------ 2 root root 4096 Jun 22 10:40 Modelos_Sem_Hyper
# -rw------- 1 root root 1187 Apr 17 15:02 README.roboflow.txt
# drwx------ 2 root root 4096 Apr 29 14:54 runs
# drwx------ 2 root root 4096 Apr 17 15:05 test
# drwx------ 2 root root 4096 Apr 17 15:05 train
# drwx------ 2 root root 4096 Apr 17 15:05 valid

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.2.39-py3-none-any.whl (792 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 792.7/792.7 kB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2.0.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.25.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (3.7.1)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.8.0.76)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.11.4)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.3.0+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.18.0+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.66.4)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.0.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.13.1)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2024.6.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvjitlink_cu12-12.5.40-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 56.2 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, ultralytics-thop, ultralytics
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.40 nvidia-nvtx-cu12-12.1.105 ultralytics-8.2.39 ultralytics-thop-2.0.0

# %%
import os
import ultralytics
from ultralytics import YOLO

ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.39 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# Setup complete ✅ (12 CPUs, 83.5 GB RAM, 30.2/201.2 GB disk)

# %%
from ultralytics import YOLO

# Initialize the YOLO model
model = YOLO('yolov9t.yaml')

# Tune hyperparameters on COCO8 for 30 epochs
model.tune(data=os.path.join(ROOT_DIR,"dataColab.yaml"),
                  epochs=30, iterations=30,
                  optimizer='AdamW',
                  plots=True,
                  save=True,
                  val=True,
                  batch = -1,
                  device = 'cuda'
          )
# Out:
# Tuner: Initialized Tuner instance with 'tune_dir=runs/detect/tune5'
# Tuner: 💡 Learn about tuning at https://docs.ultralytics.com/guides/hyperparameter-tuning
# Tuner: Starting iteration 1/30 with hyperparameters: {'lr0': 0.01, 'lrf': 0.01, 'momentum': 0.937, 'weight_decay': 0.0005, 'warmup_epochs': 3.0, 'warmup_momentum': 0.8, 'box': 7.5, 'cls': 0.5, 'dfl': 1.5, 'hsv_h': 0.015, 'hsv_s': 0.7, 'hsv_v': 0.4, 'degrees': 0.0, 'translate': 0.1, 'scale': 0.5, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.5, 'bgr': 0.0, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune5/tune_scatter_plots.png
# Saved runs/detect/tune5/tune_fitness.png
#
# Tuner: 1/30 iterations complete ✅ (342.63s)
# Tuner: Results saved to runs/detect/tune5
# Tuner: Best fitness=0.4128 observed at iteration 1
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.7375, 'metrics/recall(B)': 0.58788, 'metrics/mAP50(B)': 0.66773, 'metrics/mAP50-95(B)': 0.38447, 'val/box_loss': 1.523, 'val/cls_loss': 1.40569, 'val/dfl_loss': 1.68633, 'fitness': 0.4128}
# Tuner: Best fitness model is runs/detect/train5
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune5/best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.01
# momentum: 0.937
# weight_decay: 0.0005
# warmup_epochs: 3.0
# warmup_momentum: 0.8
# box: 7.5
# cls: 0.5
# dfl: 1.5
# hsv_h: 0.015
# hsv_s: 0.7
# hsv_v: 0.4
# degrees: 0.0
# translate: 0.1
# scale: 0.5
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.5
# bgr: 0.0
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 2/30 with hyperparameters: {'lr0': 0.01032, 'lrf': 0.00909, 'momentum': 0.97225, 'weight_decay': 0.00049, 'warmup_epochs': 3.27243, 'warmup_momentum': 0.65593, 'box': 9.33121, 'cls': 0.51003, 'dfl': 1.36452, 'hsv_h': 0.01471, 'hsv_s': 0.7, 'hsv_v': 0.39824, 'degrees': 0.0, 'translate': 0.11716, 'scale': 0.47093, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.57969, 'bgr': 0.0, 'mosaic': 0.97424, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune5/tune_scatter_plots.png
# Saved runs/detect/tune5/tune_fitness.png
#
# Tuner: 2/30 iterations complete ✅ (686.11s)
# Tuner: Results saved to runs/detect/tune5
# Tuner: Best fitness=0.4128 observed at iteration 1
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.7375, 'metrics/recall(B)': 0.58788, 'metrics/mAP50(B)': 0.66773, 'metrics/mAP50-95(B)': 0.38447, 'val/box_loss': 1.523, 'val/cls_loss': 1.40569, 'val/dfl_loss': 1.68633, 'fitness': 0.4128}
# Tuner: Best fitness model is runs/detect/train5
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune5/best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.01
# momentum: 0.937
# weight_decay: 0.0005
# warmup_epochs: 3.0
# warmup_momentum: 0.8
# box: 7.5
# cls: 0.5
# dfl: 1.5
# hsv_h: 0.015
# hsv_s: 0.7
# hsv_v: 0.4
# degrees: 0.0
# translate: 0.1
# scale: 0.5
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.5
# bgr: 0.0
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 3/30 with hyperparameters: {'lr0': 0.01, 'lrf': 0.00912, 'momentum': 0.96507, 'weight_decay': 0.00041, 'warmup_epochs': 2.57428, 'warmup_momentum': 0.78577, 'box': 7.98066, 'cls': 0.50558, 'dfl': 1.41102, 'hsv_h': 0.0132, 'hsv_s': 0.7, 'hsv_v': 0.45052, 'degrees': 0.0, 'translate': 0.1, 'scale': 0.50733, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.50205, 'bgr': 0.0, 'mosaic': 0.94105, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune5/tune_scatter_plots.png
# Saved runs/detect/tune5/tune_fitness.png
#
# Tuner: 3/30 iterations complete ✅ (1031.89s)
# Tuner: Results saved to runs/detect/tune5
# Tuner: Best fitness=0.4128 observed at iteration 1
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.7375, 'metrics/recall(B)': 0.58788, 'metrics/mAP50(B)': 0.66773, 'metrics/mAP50-95(B)': 0.38447, 'val/box_loss': 1.523, 'val/cls_loss': 1.40569, 'val/dfl_loss': 1.68633, 'fitness': 0.4128}
# Tuner: Best fitness model is runs/detect/train5
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune5/best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.01
# momentum: 0.937
# weight_decay: 0.0005
# warmup_epochs: 3.0
# warmup_momentum: 0.8
# box: 7.5
# cls: 0.5
# dfl: 1.5
# hsv_h: 0.015
# hsv_s: 0.7
# hsv_v: 0.4
# degrees: 0.0
# translate: 0.1
# scale: 0.5
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.5
# bgr: 0.0
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 4/30 with hyperparameters: {'lr0': 0.01034, 'lrf': 0.0114, 'momentum': 0.97265, 'weight_decay': 0.00053, 'warmup_epochs': 2.88887, 'warmup_momentum': 0.8, 'box': 6.56516, 'cls': 0.5, 'dfl': 1.79441, 'hsv_h': 0.01495, 'hsv_s': 0.72863, 'hsv_v': 0.37499, 'degrees': 0.0, 'translate': 0.11484, 'scale': 0.5446, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.52684, 'bgr': 0.0, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune5/tune_scatter_plots.png
# Saved runs/detect/tune5/tune_fitness.png
#
# Tuner: 4/30 iterations complete ✅ (1379.24s)
# Tuner: Results saved to runs/detect/tune5
# Tuner: Best fitness=0.4128 observed at iteration 1
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.7375, 'metrics/recall(B)': 0.58788, 'metrics/mAP50(B)': 0.66773, 'metrics/mAP50-95(B)': 0.38447, 'val/box_loss': 1.523, 'val/cls_loss': 1.40569, 'val/dfl_loss': 1.68633, 'fitness': 0.4128}
# Tuner: Best fitness model is runs/detect/train5
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune5/best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.01
# momentum: 0.937
# weight_decay: 0.0005
# warmup_epochs: 3.0
# warmup_momentum: 0.8
# box: 7.5
# cls: 0.5
# dfl: 1.5
# hsv_h: 0.015
# hsv_s: 0.7
# hsv_v: 0.4
# degrees: 0.0
# translate: 0.1
# scale: 0.5
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.5
# bgr: 0.0
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 5/30 with hyperparameters: {'lr0': 0.01027, 'lrf': 0.01, 'momentum': 0.90417, 'weight_decay': 0.0005, 'warmup_epochs': 3.0, 'warmup_momentum': 0.8, 'box': 6.42975, 'cls': 0.55092, 'dfl': 1.16229, 'hsv_h': 0.01801, 'hsv_s': 0.87128, 'hsv_v': 0.3546, 'degrees': 0.0, 'translate': 0.09397, 'scale': 0.55701, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.45706, 'bgr': 0.0, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune5/tune_scatter_plots.png
# Saved runs/detect/tune5/tune_fitness.png
#
# Tuner: 5/30 iterations complete ✅ (1724.59s)
# Tuner: Results saved to runs/detect/tune5
# Tuner: Best fitness=0.4128 observed at iteration 1
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.7375, 'metrics/recall(B)': 0.58788, 'metrics/mAP50(B)': 0.66773, 'metrics/mAP50-95(B)': 0.38447, 'val/box_loss': 1.523, 'val/cls_loss': 1.40569, 'val/dfl_loss': 1.68633, 'fitness': 0.4128}
# Tuner: Best fitness model is runs/detect/train5
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune5/best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.01
# momentum: 0.937
# weight_decay: 0.0005
# warmup_epochs: 3.0
# warmup_momentum: 0.8
# box: 7.5
# cls: 0.5
# dfl: 1.5
# hsv_h: 0.015
# hsv_s: 0.7
# hsv_v: 0.4
# degrees: 0.0
# translate: 0.1
# scale: 0.5
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.5
# bgr: 0.0
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 6/30 with hyperparameters: {'lr0': 0.01043, 'lrf': 0.00992, 'momentum': 0.9487, 'weight_decay': 0.00041, 'warmup_epochs': 2.52859, 'warmup_momentum': 0.81433, 'box': 8.6184, 'cls': 0.58462, 'dfl': 1.39766, 'hsv_h': 0.0132, 'hsv_s': 0.64539, 'hsv_v': 0.42167, 'degrees': 0.0, 'translate': 0.08796, 'scale': 0.55394, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.51283, 'bgr': 0.0, 'mosaic': 0.87901, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune5/tune_scatter_plots.png
# Saved runs/detect/tune5/tune_fitness.png
#
# Tuner: 6/30 iterations complete ✅ (2069.44s)
# Tuner: Results saved to runs/detect/tune5
# Tuner: Best fitness=0.4128 observed at iteration 1
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.7375, 'metrics/recall(B)': 0.58788, 'metrics/mAP50(B)': 0.66773, 'metrics/mAP50-95(B)': 0.38447, 'val/box_loss': 1.523, 'val/cls_loss': 1.40569, 'val/dfl_loss': 1.68633, 'fitness': 0.4128}
# Tuner: Best fitness model is runs/detect/train5
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune5/best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.01
# momentum: 0.937
# weight_decay: 0.0005
# warmup_epochs: 3.0
# warmup_momentum: 0.8
# box: 7.5
# cls: 0.5
# dfl: 1.5
# hsv_h: 0.015
# hsv_s: 0.7
# hsv_v: 0.4
# degrees: 0.0
# translate: 0.1
# scale: 0.5
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.5
# bgr: 0.0
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 7/30 with hyperparameters: {'lr0': 0.01001, 'lrf': 0.01142, 'momentum': 0.98, 'weight_decay': 0.00041, 'warmup_epochs': 2.52296, 'warmup_momentum': 0.83849, 'box': 8.36877, 'cls': 0.6162, 'dfl': 1.74201, 'hsv_h': 0.01017, 'hsv_s': 0.58846, 'hsv_v': 0.42167, 'degrees': 0.0, 'translate': 0.08532, 'scale': 0.55702, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.46157, 'bgr': 0.0, 'mosaic': 0.87901, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune5/tune_scatter_plots.png
# Saved runs/detect/tune5/tune_fitness.png
#
# Tuner: 7/30 iterations complete ✅ (2414.29s)
# Tuner: Results saved to runs/detect/tune5
# Tuner: Best fitness=0.4128 observed at iteration 1
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.7375, 'metrics/recall(B)': 0.58788, 'metrics/mAP50(B)': 0.66773, 'metrics/mAP50-95(B)': 0.38447, 'val/box_loss': 1.523, 'val/cls_loss': 1.40569, 'val/dfl_loss': 1.68633, 'fitness': 0.4128}
# Tuner: Best fitness model is runs/detect/train5
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune5/best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.01
# momentum: 0.937
# weight_decay: 0.0005
# warmup_epochs: 3.0
# warmup_momentum: 0.8
# box: 7.5
# cls: 0.5
# dfl: 1.5
# hsv_h: 0.015
# hsv_s: 0.7
# hsv_v: 0.4
# degrees: 0.0
# translate: 0.1
# scale: 0.5
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.5
# bgr: 0.0
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 8/30 with hyperparameters: {'lr0': 0.01017, 'lrf': 0.01047, 'momentum': 0.87989, 'weight_decay': 0.00051, 'warmup_epochs': 2.9626, 'warmup_momentum': 0.79085, 'box': 6.36385, 'cls': 0.55092, 'dfl': 1.13327, 'hsv_h': 0.01801, 'hsv_s': 0.87437, 'hsv_v': 0.34011, 'degrees': 0.0, 'translate': 0.09034, 'scale': 0.55963, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.4459, 'bgr': 0.0, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune5/tune_scatter_plots.png
# Saved runs/detect/tune5/tune_fitness.png
#
# Tuner: 8/30 iterations complete ✅ (2758.95s)
# Tuner: Results saved to runs/detect/tune5
# Tuner: Best fitness=0.43029 observed at iteration 8
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.69694, 'metrics/recall(B)': 0.62727, 'metrics/mAP50(B)': 0.69225, 'metrics/mAP50-95(B)': 0.40118, 'val/box_loss': 1.29398, 'val/cls_loss': 1.49844, 'val/dfl_loss': 1.30238, 'fitness': 0.43029}
# Tuner: Best fitness model is runs/detect/train12
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune5/best_hyperparameters.yaml'
#
# lr0: 0.01017
# lrf: 0.01047
# momentum: 0.87989
# weight_decay: 0.00051
# warmup_epochs: 2.9626
# warmup_momentum: 0.79085
# box: 6.36385
# cls: 0.55092
# dfl: 1.13327
# hsv_h: 0.01801
# hsv_s: 0.87437
# hsv_v: 0.34011
# degrees: 0.0
# translate: 0.09034
# scale: 0.55963
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.4459
# bgr: 0.0
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 9/30 with hyperparameters: {'lr0': 0.01015, 'lrf': 0.01047, 'momentum': 0.87927, 'weight_decay': 0.00051, 'warmup_epochs': 2.96385, 'warmup_momentum': 0.79085, 'box': 6.36849, 'cls': 0.5513, 'dfl': 1.13872, 'hsv_h': 0.01807, 'hsv_s': 0.87565, 'hsv_v': 0.33963, 'degrees': 0.0, 'translate': 0.09047, 'scale': 0.55991, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.4459, 'bgr': 0.0, 'mosaic': 0.99654, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune5/tune_scatter_plots.png
# Saved runs/detect/tune5/tune_fitness.png
#
# Tuner: 9/30 iterations complete ✅ (3103.53s)
# Tuner: Results saved to runs/detect/tune5
# Tuner: Best fitness=0.43029 observed at iteration 8
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.69694, 'metrics/recall(B)': 0.62727, 'metrics/mAP50(B)': 0.69225, 'metrics/mAP50-95(B)': 0.40118, 'val/box_loss': 1.29398, 'val/cls_loss': 1.49844, 'val/dfl_loss': 1.30238, 'fitness': 0.43029}
# Tuner: Best fitness model is runs/detect/train12
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune5/best_hyperparameters.yaml'
#
# lr0: 0.01017
# lrf: 0.01047
# momentum: 0.87989
# weight_decay: 0.00051
# warmup_epochs: 2.9626
# warmup_momentum: 0.79085
# box: 6.36385
# cls: 0.55092
# dfl: 1.13327
# hsv_h: 0.01801
# hsv_s: 0.87437
# hsv_v: 0.34011
# degrees: 0.0
# translate: 0.09034
# scale: 0.55963
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.4459
# bgr: 0.0
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 10/30 with hyperparameters: {'lr0': 0.01017, 'lrf': 0.00963, 'momentum': 0.89257, 'weight_decay': 0.00059, 'warmup_epochs': 3.23205, 'warmup_momentum': 0.78953, 'box': 7.10529, 'cls': 0.55092, 'dfl': 1.07387, 'hsv_h': 0.01732, 'hsv_s': 0.87437, 'hsv_v': 0.34011, 'degrees': 0.0, 'translate': 0.09034, 'scale': 0.48639, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.45648, 'bgr': 0.0, 'mosaic': 0.92724, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune5/tune_scatter_plots.png
# Saved runs/detect/tune5/tune_fitness.png
#
# Tuner: 10/30 iterations complete ✅ (3450.12s)
# Tuner: Results saved to runs/detect/tune5
# Tuner: Best fitness=0.43029 observed at iteration 8
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.69694, 'metrics/recall(B)': 0.62727, 'metrics/mAP50(B)': 0.69225, 'metrics/mAP50-95(B)': 0.40118, 'val/box_loss': 1.29398, 'val/cls_loss': 1.49844, 'val/dfl_loss': 1.30238, 'fitness': 0.43029}
# Tuner: Best fitness model is runs/detect/train12
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune5/best_hyperparameters.yaml'
#
# lr0: 0.01017
# lrf: 0.01047
# momentum: 0.87989
# weight_decay: 0.00051
# warmup_epochs: 2.9626
# warmup_momentum: 0.79085
# box: 6.36385
# cls: 0.55092
# dfl: 1.13327
# hsv_h: 0.01801
# hsv_s: 0.87437
# hsv_v: 0.34011
# degrees: 0.0
# translate: 0.09034
# scale: 0.55963
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.4459
# bgr: 0.0
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 11/30 with hyperparameters: {'lr0': 0.01109, 'lrf': 0.00964, 'momentum': 0.90285, 'weight_decay': 0.00062, 'warmup_epochs': 2.96385, 'warmup_momentum': 0.66301, 'box': 5.43208, 'cls': 0.5513, 'dfl': 1.44381, 'hsv_h': 0.02012, 'hsv_s': 0.9, 'hsv_v': 0.29339, 'degrees': 0.0, 'translate': 0.09047, 'scale': 0.59598, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.45137, 'bgr': 0.0, 'mosaic': 0.86345, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune5/tune_scatter_plots.png
# Saved runs/detect/tune5/tune_fitness.png
#
# Tuner: 11/30 iterations complete ✅ (3795.78s)
# Tuner: Results saved to runs/detect/tune5
# Tuner: Best fitness=0.43029 observed at iteration 8
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.69694, 'metrics/recall(B)': 0.62727, 'metrics/mAP50(B)': 0.69225, 'metrics/mAP50-95(B)': 0.40118, 'val/box_loss': 1.29398, 'val/cls_loss': 1.49844, 'val/dfl_loss': 1.30238, 'fitness': 0.43029}
# Tuner: Best fitness model is runs/detect/train12
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune5/best_hyperparameters.yaml'
#
# lr0: 0.01017
# lrf: 0.01047
# momentum: 0.87989
# weight_decay: 0.00051
# warmup_epochs: 2.9626
# warmup_momentum: 0.79085
# box: 6.36385
# cls: 0.55092
# dfl: 1.13327
# hsv_h: 0.01801
# hsv_s: 0.87437
# hsv_v: 0.34011
# degrees: 0.0
# translate: 0.09034
# scale: 0.55963
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.4459
# bgr: 0.0
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 12/30 with hyperparameters: {'lr0': 0.01013, 'lrf': 0.01047, 'momentum': 0.87927, 'weight_decay': 0.00045, 'warmup_epochs': 2.77263, 'warmup_momentum': 0.79314, 'box': 6.36849, 'cls': 0.48103, 'dfl': 1.17672, 'hsv_h': 0.01949, 'hsv_s': 0.87565, 'hsv_v': 0.33963, 'degrees': 0.0, 'translate': 0.08838, 'scale': 0.55991, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.4459, 'bgr': 0.0, 'mosaic': 0.86777, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune5/tune_scatter_plots.png
# Saved runs/detect/tune5/tune_fitness.png
#
# Tuner: 12/30 iterations complete ✅ (4141.72s)
# Tuner: Results saved to runs/detect/tune5
# Tuner: Best fitness=0.43029 observed at iteration 8
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.69694, 'metrics/recall(B)': 0.62727, 'metrics/mAP50(B)': 0.69225, 'metrics/mAP50-95(B)': 0.40118, 'val/box_loss': 1.29398, 'val/cls_loss': 1.49844, 'val/dfl_loss': 1.30238, 'fitness': 0.43029}
# Tuner: Best fitness model is runs/detect/train12
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune5/best_hyperparameters.yaml'
#
# lr0: 0.01017
# lrf: 0.01047
# momentum: 0.87989
# weight_decay: 0.00051
# warmup_epochs: 2.9626
# warmup_momentum: 0.79085
# box: 6.36385
# cls: 0.55092
# dfl: 1.13327
# hsv_h: 0.01801
# hsv_s: 0.87437
# hsv_v: 0.34011
# degrees: 0.0
# translate: 0.09034
# scale: 0.55963
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.4459
# bgr: 0.0
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 13/30 with hyperparameters: {'lr0': 0.01017, 'lrf': 0.00963, 'momentum': 0.8765, 'weight_decay': 0.00056, 'warmup_epochs': 2.99093, 'warmup_momentum': 0.80142, 'box': 6.54366, 'cls': 0.48574, 'dfl': 1.1667, 'hsv_h': 0.01792, 'hsv_s': 0.89265, 'hsv_v': 0.34369, 'degrees': 0.0, 'translate': 0.09034, 'scale': 0.46108, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.45269, 'bgr': 0.0, 'mosaic': 0.92724, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune5/tune_scatter_plots.png
# Saved runs/detect/tune5/tune_fitness.png
#
# Tuner: 13/30 iterations complete ✅ (4487.32s)
# Tuner: Results saved to runs/detect/tune5
# Tuner: Best fitness=0.43029 observed at iteration 8
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.69694, 'metrics/recall(B)': 0.62727, 'metrics/mAP50(B)': 0.69225, 'metrics/mAP50-95(B)': 0.40118, 'val/box_loss': 1.29398, 'val/cls_loss': 1.49844, 'val/dfl_loss': 1.30238, 'fitness': 0.43029}
# Tuner: Best fitness model is runs/detect/train12
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune5/best_hyperparameters.yaml'
#
# lr0: 0.01017
# lrf: 0.01047
# momentum: 0.87989
# weight_decay: 0.00051
# warmup_epochs: 2.9626
# warmup_momentum: 0.79085
# box: 6.36385
# cls: 0.55092
# dfl: 1.13327
# hsv_h: 0.01801
# hsv_s: 0.87437
# hsv_v: 0.34011
# degrees: 0.0
# translate: 0.09034
# scale: 0.55963
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.4459
# bgr: 0.0
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 14/30 with hyperparameters: {'lr0': 0.01277, 'lrf': 0.01304, 'momentum': 0.88381, 'weight_decay': 0.00043, 'warmup_epochs': 2.77263, 'warmup_momentum': 0.79806, 'box': 5.12611, 'cls': 0.43113, 'dfl': 1.17672, 'hsv_h': 0.01924, 'hsv_s': 0.71182, 'hsv_v': 0.34654, 'degrees': 0.0, 'translate': 0.08838, 'scale': 0.55991, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.48077, 'bgr': 0.0, 'mosaic': 0.92171, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune5/tune_scatter_plots.png
# Saved runs/detect/tune5/tune_fitness.png
#
# Tuner: 14/30 iterations complete ✅ (4834.48s)
# Tuner: Results saved to runs/detect/tune5
# Tuner: Best fitness=0.43029 observed at iteration 8
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.69694, 'metrics/recall(B)': 0.62727, 'metrics/mAP50(B)': 0.69225, 'metrics/mAP50-95(B)': 0.40118, 'val/box_loss': 1.29398, 'val/cls_loss': 1.49844, 'val/dfl_loss': 1.30238, 'fitness': 0.43029}
# Tuner: Best fitness model is runs/detect/train12
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune5/best_hyperparameters.yaml'
#
# lr0: 0.01017
# lrf: 0.01047
# momentum: 0.87989
# weight_decay: 0.00051
# warmup_epochs: 2.9626
# warmup_momentum: 0.79085
# box: 6.36385
# cls: 0.55092
# dfl: 1.13327
# hsv_h: 0.01801
# hsv_s: 0.87437
# hsv_v: 0.34011
# degrees: 0.0
# translate: 0.09034
# scale: 0.55963
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.4459
# bgr: 0.0
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 15/30 with hyperparameters: {'lr0': 0.00951, 'lrf': 0.01047, 'momentum': 0.87164, 'weight_decay': 0.0004, 'warmup_epochs': 3.17432, 'warmup_momentum': 0.79315, 'box': 7.20983, 'cls': 0.58434, 'dfl': 1.17943, 'hsv_h': 0.01901, 'hsv_s': 0.81958, 'hsv_v': 0.28226, 'degrees': 0.0, 'translate': 0.07462, 'scale': 0.46414, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.4459, 'bgr': 0.0, 'mosaic': 0.63725, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune5/tune_scatter_plots.png
# Saved runs/detect/tune5/tune_fitness.png
#
# Tuner: 15/30 iterations complete ✅ (5179.92s)
# Tuner: Results saved to runs/detect/tune5
# Tuner: Best fitness=0.45693 observed at iteration 15
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.76357, 'metrics/recall(B)': 0.61212, 'metrics/mAP50(B)': 0.7159, 'metrics/mAP50-95(B)': 0.42815, 'val/box_loss': 1.40391, 'val/cls_loss': 1.52279, 'val/dfl_loss': 1.28184, 'fitness': 0.45693}
# Tuner: Best fitness model is runs/detect/train19
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune5/best_hyperparameters.yaml'
#
# lr0: 0.00951
# lrf: 0.01047
# momentum: 0.87164
# weight_decay: 0.0004
# warmup_epochs: 3.17432
# warmup_momentum: 0.79315
# box: 7.20983
# cls: 0.58434
# dfl: 1.17943
# hsv_h: 0.01901
# hsv_s: 0.81958
# hsv_v: 0.28226
# degrees: 0.0
# translate: 0.07462
# scale: 0.46414
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.4459
# bgr: 0.0
# mosaic: 0.63725
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 16/30 with hyperparameters: {'lr0': 0.00951, 'lrf': 0.00971, 'momentum': 0.87164, 'weight_decay': 0.00046, 'warmup_epochs': 3.81771, 'warmup_momentum': 0.79315, 'box': 7.20983, 'cls': 0.58434, 'dfl': 1.15099, 'hsv_h': 0.01788, 'hsv_s': 0.64672, 'hsv_v': 0.30459, 'degrees': 0.0, 'translate': 0.07462, 'scale': 0.42731, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.42757, 'bgr': 0.0, 'mosaic': 0.53968, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune5/tune_scatter_plots.png
# Saved runs/detect/tune5/tune_fitness.png
#
# Tuner: 16/30 iterations complete ✅ (5522.36s)
# Tuner: Results saved to runs/detect/tune5
# Tuner: Best fitness=0.45693 observed at iteration 15
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.76357, 'metrics/recall(B)': 0.61212, 'metrics/mAP50(B)': 0.7159, 'metrics/mAP50-95(B)': 0.42815, 'val/box_loss': 1.40391, 'val/cls_loss': 1.52279, 'val/dfl_loss': 1.28184, 'fitness': 0.45693}
# Tuner: Best fitness model is runs/detect/train19
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune5/best_hyperparameters.yaml'
#
# lr0: 0.00951
# lrf: 0.01047
# momentum: 0.87164
# weight_decay: 0.0004
# warmup_epochs: 3.17432
# warmup_momentum: 0.79315
# box: 7.20983
# cls: 0.58434
# dfl: 1.17943
# hsv_h: 0.01901
# hsv_s: 0.81958
# hsv_v: 0.28226
# degrees: 0.0
# translate: 0.07462
# scale: 0.46414
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.4459
# bgr: 0.0
# mosaic: 0.63725
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 17/30 with hyperparameters: {'lr0': 0.00951, 'lrf': 0.01109, 'momentum': 0.86319, 'weight_decay': 0.00043, 'warmup_epochs': 3.17432, 'warmup_momentum': 0.79414, 'box': 7.00127, 'cls': 0.54804, 'dfl': 1.205, 'hsv_h': 0.01868, 'hsv_s': 0.82856, 'hsv_v': 0.28226, 'degrees': 0.0, 'translate': 0.07285, 'scale': 0.47763, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.4459, 'bgr': 0.0, 'mosaic': 0.73385, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune5/tune_scatter_plots.png
# Saved runs/detect/tune5/tune_fitness.png
#
# Tuner: 17/30 iterations complete ✅ (5866.65s)
# Tuner: Results saved to runs/detect/tune5
# Tuner: Best fitness=0.45693 observed at iteration 15
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.76357, 'metrics/recall(B)': 0.61212, 'metrics/mAP50(B)': 0.7159, 'metrics/mAP50-95(B)': 0.42815, 'val/box_loss': 1.40391, 'val/cls_loss': 1.52279, 'val/dfl_loss': 1.28184, 'fitness': 0.45693}
# Tuner: Best fitness model is runs/detect/train19
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune5/best_hyperparameters.yaml'
#
# lr0: 0.00951
# lrf: 0.01047
# momentum: 0.87164
# weight_decay: 0.0004
# warmup_epochs: 3.17432
# warmup_momentum: 0.79315
# box: 7.20983
# cls: 0.58434
# dfl: 1.17943
# hsv_h: 0.01901
# hsv_s: 0.81958
# hsv_v: 0.28226
# degrees: 0.0
# translate: 0.07462
# scale: 0.46414
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.4459
# bgr: 0.0
# mosaic: 0.63725
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 18/30 with hyperparameters: {'lr0': 0.00948, 'lrf': 0.01098, 'momentum': 0.85547, 'weight_decay': 0.00038, 'warmup_epochs': 3.30655, 'warmup_momentum': 0.76205, 'box': 6.8362, 'cls': 0.57749, 'dfl': 1.08745, 'hsv_h': 0.01837, 'hsv_s': 0.80752, 'hsv_v': 0.28226, 'degrees': 0.0, 'translate': 0.07794, 'scale': 0.46957, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.42158, 'bgr': 0.0, 'mosaic': 0.6279, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune5/tune_scatter_plots.png
# Saved runs/detect/tune5/tune_fitness.png
#
# Tuner: 18/30 iterations complete ✅ (6211.94s)
# Tuner: Results saved to runs/detect/tune5
# Tuner: Best fitness=0.45693 observed at iteration 15
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.76357, 'metrics/recall(B)': 0.61212, 'metrics/mAP50(B)': 0.7159, 'metrics/mAP50-95(B)': 0.42815, 'val/box_loss': 1.40391, 'val/cls_loss': 1.52279, 'val/dfl_loss': 1.28184, 'fitness': 0.45693}
# Tuner: Best fitness model is runs/detect/train19
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune5/best_hyperparameters.yaml'
#
# lr0: 0.00951
# lrf: 0.01047
# momentum: 0.87164
# weight_decay: 0.0004
# warmup_epochs: 3.17432
# warmup_momentum: 0.79315
# box: 7.20983
# cls: 0.58434
# dfl: 1.17943
# hsv_h: 0.01901
# hsv_s: 0.81958
# hsv_v: 0.28226
# degrees: 0.0
# translate: 0.07462
# scale: 0.46414
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.4459
# bgr: 0.0
# mosaic: 0.63725
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 19/30 with hyperparameters: {'lr0': 0.00964, 'lrf': 0.01047, 'momentum': 0.84076, 'weight_decay': 0.00038, 'warmup_epochs': 3.34784, 'warmup_momentum': 0.7808, 'box': 7.20983, 'cls': 0.56895, 'dfl': 1.12568, 'hsv_h': 0.01934, 'hsv_s': 0.75989, 'hsv_v': 0.27444, 'degrees': 0.0, 'translate': 0.0691, 'scale': 0.47094, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.40429, 'bgr': 0.0, 'mosaic': 0.58846, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune5/tune_scatter_plots.png
# Saved runs/detect/tune5/tune_fitness.png
#
# Tuner: 19/30 iterations complete ✅ (6557.39s)
# Tuner: Results saved to runs/detect/tune5
# Tuner: Best fitness=0.45693 observed at iteration 15
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.76357, 'metrics/recall(B)': 0.61212, 'metrics/mAP50(B)': 0.7159, 'metrics/mAP50-95(B)': 0.42815, 'val/box_loss': 1.40391, 'val/cls_loss': 1.52279, 'val/dfl_loss': 1.28184, 'fitness': 0.45693}
# Tuner: Best fitness model is runs/detect/train19
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune5/best_hyperparameters.yaml'
#
# lr0: 0.00951
# lrf: 0.01047
# momentum: 0.87164
# weight_decay: 0.0004
# warmup_epochs: 3.17432
# warmup_momentum: 0.79315
# box: 7.20983
# cls: 0.58434
# dfl: 1.17943
# hsv_h: 0.01901
# hsv_s: 0.81958
# hsv_v: 0.28226
# degrees: 0.0
# translate: 0.07462
# scale: 0.46414
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.4459
# bgr: 0.0
# mosaic: 0.63725
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 20/30 with hyperparameters: {'lr0': 0.01054, 'lrf': 0.00968, 'momentum': 0.88129, 'weight_decay': 0.00029, 'warmup_epochs': 3.05775, 'warmup_momentum': 0.79374, 'box': 8.88498, 'cls': 0.4871, 'dfl': 1.06719, 'hsv_h': 0.0186, 'hsv_s': 0.84371, 'hsv_v': 0.28226, 'degrees': 0.0, 'translate': 0.07462, 'scale': 0.50613, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.40116, 'bgr': 0.0, 'mosaic': 0.69347, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune5/tune_scatter_plots.png
# Saved runs/detect/tune5/tune_fitness.png
#
# Tuner: 20/30 iterations complete ✅ (6900.63s)
# Tuner: Results saved to runs/detect/tune5
# Tuner: Best fitness=0.45693 observed at iteration 15
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.76357, 'metrics/recall(B)': 0.61212, 'metrics/mAP50(B)': 0.7159, 'metrics/mAP50-95(B)': 0.42815, 'val/box_loss': 1.40391, 'val/cls_loss': 1.52279, 'val/dfl_loss': 1.28184, 'fitness': 0.45693}
# Tuner: Best fitness model is runs/detect/train19
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune5/best_hyperparameters.yaml'
#
# lr0: 0.00951
# lrf: 0.01047
# momentum: 0.87164
# weight_decay: 0.0004
# warmup_epochs: 3.17432
# warmup_momentum: 0.79315
# box: 7.20983
# cls: 0.58434
# dfl: 1.17943
# hsv_h: 0.01901
# hsv_s: 0.81958
# hsv_v: 0.28226
# degrees: 0.0
# translate: 0.07462
# scale: 0.46414
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.4459
# bgr: 0.0
# mosaic: 0.63725
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 21/30 with hyperparameters: {'lr0': 0.00914, 'lrf': 0.00598, 'momentum': 0.86109, 'weight_decay': 0.0005, 'warmup_epochs': 3.17432, 'warmup_momentum': 0.89217, 'box': 6.65795, 'cls': 0.54804, 'dfl': 1.05668, 'hsv_h': 0.0184, 'hsv_s': 0.737, 'hsv_v': 0.28226, 'degrees': 0.0, 'translate': 0.11234, 'scale': 0.47763, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.48586, 'bgr': 0.0, 'mosaic': 0.76606, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune5/tune_scatter_plots.png
# Saved runs/detect/tune5/tune_fitness.png
#
# Tuner: 21/30 iterations complete ✅ (7245.92s)
# Tuner: Results saved to runs/detect/tune5
# Tuner: Best fitness=0.45693 observed at iteration 15
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.76357, 'metrics/recall(B)': 0.61212, 'metrics/mAP50(B)': 0.7159, 'metrics/mAP50-95(B)': 0.42815, 'val/box_loss': 1.40391, 'val/cls_loss': 1.52279, 'val/dfl_loss': 1.28184, 'fitness': 0.45693}
# Tuner: Best fitness model is runs/detect/train19
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune5/best_hyperparameters.yaml'
#
# lr0: 0.00951
# lrf: 0.01047
# momentum: 0.87164
# weight_decay: 0.0004
# warmup_epochs: 3.17432
# warmup_momentum: 0.79315
# box: 7.20983
# cls: 0.58434
# dfl: 1.17943
# hsv_h: 0.01901
# hsv_s: 0.81958
# hsv_v: 0.28226
# degrees: 0.0
# translate: 0.07462
# scale: 0.46414
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.4459
# bgr: 0.0
# mosaic: 0.63725
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 22/30 with hyperparameters: {'lr0': 0.00964, 'lrf': 0.01005, 'momentum': 0.86592, 'weight_decay': 0.00036, 'warmup_epochs': 3.28746, 'warmup_momentum': 0.72887, 'box': 7.16037, 'cls': 0.57072, 'dfl': 1.09549, 'hsv_h': 0.01949, 'hsv_s': 0.75989, 'hsv_v': 0.27444, 'degrees': 0.0, 'translate': 0.0691, 'scale': 0.4595, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.43069, 'bgr': 0.0, 'mosaic': 0.58846, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune5/tune_scatter_plots.png
# Saved runs/detect/tune5/tune_fitness.png
#
# Tuner: 22/30 iterations complete ✅ (7591.15s)
# Tuner: Results saved to runs/detect/tune5
# Tuner: Best fitness=0.45693 observed at iteration 15
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.76357, 'metrics/recall(B)': 0.61212, 'metrics/mAP50(B)': 0.7159, 'metrics/mAP50-95(B)': 0.42815, 'val/box_loss': 1.40391, 'val/cls_loss': 1.52279, 'val/dfl_loss': 1.28184, 'fitness': 0.45693}
# Tuner: Best fitness model is runs/detect/train19
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune5/best_hyperparameters.yaml'
#
# lr0: 0.00951
# lrf: 0.01047
# momentum: 0.87164
# weight_decay: 0.0004
# warmup_epochs: 3.17432
# warmup_momentum: 0.79315
# box: 7.20983
# cls: 0.58434
# dfl: 1.17943
# hsv_h: 0.01901
# hsv_s: 0.81958
# hsv_v: 0.28226
# degrees: 0.0
# translate: 0.07462
# scale: 0.46414
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.4459
# bgr: 0.0
# mosaic: 0.63725
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 23/30 with hyperparameters: {'lr0': 0.01027, 'lrf': 0.01132, 'momentum': 0.87989, 'weight_decay': 0.00046, 'warmup_epochs': 2.35663, 'warmup_momentum': 0.92278, 'box': 5.97779, 'cls': 0.51013, 'dfl': 1.29014, 'hsv_h': 0.01538, 'hsv_s': 0.83901, 'hsv_v': 0.34709, 'degrees': 0.0, 'translate': 0.09034, 'scale': 0.53559, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.55793, 'bgr': 0.0, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune5/tune_scatter_plots.png
# Saved runs/detect/tune5/tune_fitness.png
#
# Tuner: 23/30 iterations complete ✅ (7943.32s)
# Tuner: Results saved to runs/detect/tune5
# Tuner: Best fitness=0.45693 observed at iteration 15
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.76357, 'metrics/recall(B)': 0.61212, 'metrics/mAP50(B)': 0.7159, 'metrics/mAP50-95(B)': 0.42815, 'val/box_loss': 1.40391, 'val/cls_loss': 1.52279, 'val/dfl_loss': 1.28184, 'fitness': 0.45693}
# Tuner: Best fitness model is runs/detect/train19
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune5/best_hyperparameters.yaml'
#
# lr0: 0.00951
# lrf: 0.01047
# momentum: 0.87164
# weight_decay: 0.0004
# warmup_epochs: 3.17432
# warmup_momentum: 0.79315
# box: 7.20983
# cls: 0.58434
# dfl: 1.17943
# hsv_h: 0.01901
# hsv_s: 0.81958
# hsv_v: 0.28226
# degrees: 0.0
# translate: 0.07462
# scale: 0.46414
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.4459
# bgr: 0.0
# mosaic: 0.63725
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 24/30 with hyperparameters: {'lr0': 0.01054, 'lrf': 0.01142, 'momentum': 0.87974, 'weight_decay': 0.00046, 'warmup_epochs': 2.36711, 'warmup_momentum': 0.9222, 'box': 5.97779, 'cls': 0.52135, 'dfl': 1.29577, 'hsv_h': 0.01554, 'hsv_s': 0.86503, 'hsv_v': 0.34834, 'degrees': 0.0, 'translate': 0.09034, 'scale': 0.54143, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.55269, 'bgr': 0.0, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune5/tune_scatter_plots.png
# Saved runs/detect/tune5/tune_fitness.png
#
# Tuner: 24/30 iterations complete ✅ (8290.62s)
# Tuner: Results saved to runs/detect/tune5
# Tuner: Best fitness=0.45693 observed at iteration 15
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.76357, 'metrics/recall(B)': 0.61212, 'metrics/mAP50(B)': 0.7159, 'metrics/mAP50-95(B)': 0.42815, 'val/box_loss': 1.40391, 'val/cls_loss': 1.52279, 'val/dfl_loss': 1.28184, 'fitness': 0.45693}
# Tuner: Best fitness model is runs/detect/train19
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune5/best_hyperparameters.yaml'
#
# lr0: 0.00951
# lrf: 0.01047
# momentum: 0.87164
# weight_decay: 0.0004
# warmup_epochs: 3.17432
# warmup_momentum: 0.79315
# box: 7.20983
# cls: 0.58434
# dfl: 1.17943
# hsv_h: 0.01901
# hsv_s: 0.81958
# hsv_v: 0.28226
# degrees: 0.0
# translate: 0.07462
# scale: 0.46414
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.4459
# bgr: 0.0
# mosaic: 0.63725
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 25/30 with hyperparameters: {'lr0': 0.00753, 'lrf': 0.0102, 'momentum': 0.89822, 'weight_decay': 0.0004, 'warmup_epochs': 3.96844, 'warmup_momentum': 0.94167, 'box': 7.20983, 'cls': 0.57987, 'dfl': 1.19188, 'hsv_h': 0.01476, 'hsv_s': 0.87344, 'hsv_v': 0.28226, 'degrees': 0.0, 'translate': 0.07511, 'scale': 0.38996, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.44271, 'bgr': 0.0, 'mosaic': 0.73419, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune5/tune_scatter_plots.png
# Saved runs/detect/tune5/tune_fitness.png
#
# Tuner: 25/30 iterations complete ✅ (8635.44s)
# Tuner: Results saved to runs/detect/tune5
# Tuner: Best fitness=0.45693 observed at iteration 15
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.76357, 'metrics/recall(B)': 0.61212, 'metrics/mAP50(B)': 0.7159, 'metrics/mAP50-95(B)': 0.42815, 'val/box_loss': 1.40391, 'val/cls_loss': 1.52279, 'val/dfl_loss': 1.28184, 'fitness': 0.45693}
# Tuner: Best fitness model is runs/detect/train19
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune5/best_hyperparameters.yaml'
#
# lr0: 0.00951
# lrf: 0.01047
# momentum: 0.87164
# weight_decay: 0.0004
# warmup_epochs: 3.17432
# warmup_momentum: 0.79315
# box: 7.20983
# cls: 0.58434
# dfl: 1.17943
# hsv_h: 0.01901
# hsv_s: 0.81958
# hsv_v: 0.28226
# degrees: 0.0
# translate: 0.07462
# scale: 0.46414
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.4459
# bgr: 0.0
# mosaic: 0.63725
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 26/30 with hyperparameters: {'lr0': 0.0116, 'lrf': 0.01047, 'momentum': 0.87473, 'weight_decay': 0.0004, 'warmup_epochs': 3.06703, 'warmup_momentum': 0.90643, 'box': 9.90352, 'cls': 0.88245, 'dfl': 1.06121, 'hsv_h': 0.02229, 'hsv_s': 0.82397, 'hsv_v': 0.32103, 'degrees': 0.0, 'translate': 0.06652, 'scale': 0.46414, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.35557, 'bgr': 0.0, 'mosaic': 0.62109, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune5/tune_scatter_plots.png
# Saved runs/detect/tune5/tune_fitness.png
#
# Tuner: 26/30 iterations complete ✅ (8980.47s)
# Tuner: Results saved to runs/detect/tune5
# Tuner: Best fitness=0.45693 observed at iteration 15
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.76357, 'metrics/recall(B)': 0.61212, 'metrics/mAP50(B)': 0.7159, 'metrics/mAP50-95(B)': 0.42815, 'val/box_loss': 1.40391, 'val/cls_loss': 1.52279, 'val/dfl_loss': 1.28184, 'fitness': 0.45693}
# Tuner: Best fitness model is runs/detect/train19
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune5/best_hyperparameters.yaml'
#
# lr0: 0.00951
# lrf: 0.01047
# momentum: 0.87164
# weight_decay: 0.0004
# warmup_epochs: 3.17432
# warmup_momentum: 0.79315
# box: 7.20983
# cls: 0.58434
# dfl: 1.17943
# hsv_h: 0.01901
# hsv_s: 0.81958
# hsv_v: 0.28226
# degrees: 0.0
# translate: 0.07462
# scale: 0.46414
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.4459
# bgr: 0.0
# mosaic: 0.63725
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 27/30 with hyperparameters: {'lr0': 0.01041, 'lrf': 0.01047, 'momentum': 0.92349, 'weight_decay': 0.00032, 'warmup_epochs': 2.23699, 'warmup_momentum': 0.69957, 'box': 6.27724, 'cls': 0.5932, 'dfl': 1.35643, 'hsv_h': 0.01511, 'hsv_s': 0.83569, 'hsv_v': 0.23895, 'degrees': 0.0, 'translate': 0.07143, 'scale': 0.44131, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.32959, 'bgr': 0.0, 'mosaic': 0.50257, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune5/tune_scatter_plots.png
# Saved runs/detect/tune5/tune_fitness.png
#
# Tuner: 27/30 iterations complete ✅ (9326.03s)
# Tuner: Results saved to runs/detect/tune5
# Tuner: Best fitness=0.45693 observed at iteration 15
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.76357, 'metrics/recall(B)': 0.61212, 'metrics/mAP50(B)': 0.7159, 'metrics/mAP50-95(B)': 0.42815, 'val/box_loss': 1.40391, 'val/cls_loss': 1.52279, 'val/dfl_loss': 1.28184, 'fitness': 0.45693}
# Tuner: Best fitness model is runs/detect/train19
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune5/best_hyperparameters.yaml'
#
# lr0: 0.00951
# lrf: 0.01047
# momentum: 0.87164
# weight_decay: 0.0004
# warmup_epochs: 3.17432
# warmup_momentum: 0.79315
# box: 7.20983
# cls: 0.58434
# dfl: 1.17943
# hsv_h: 0.01901
# hsv_s: 0.81958
# hsv_v: 0.28226
# degrees: 0.0
# translate: 0.07462
# scale: 0.46414
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.4459
# bgr: 0.0
# mosaic: 0.63725
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 28/30 with hyperparameters: {'lr0': 0.00951, 'lrf': 0.00995, 'momentum': 0.8801, 'weight_decay': 0.0004, 'warmup_epochs': 3.08629, 'warmup_momentum': 0.81699, 'box': 7.44921, 'cls': 0.55263, 'dfl': 1.15788, 'hsv_h': 0.01946, 'hsv_s': 0.81958, 'hsv_v': 0.27489, 'degrees': 0.0, 'translate': 0.06944, 'scale': 0.43446, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.45366, 'bgr': 0.0, 'mosaic': 0.61768, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune5/tune_scatter_plots.png
# Saved runs/detect/tune5/tune_fitness.png
#
# Tuner: 28/30 iterations complete ✅ (9671.05s)
# Tuner: Results saved to runs/detect/tune5
# Tuner: Best fitness=0.45693 observed at iteration 15
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.76357, 'metrics/recall(B)': 0.61212, 'metrics/mAP50(B)': 0.7159, 'metrics/mAP50-95(B)': 0.42815, 'val/box_loss': 1.40391, 'val/cls_loss': 1.52279, 'val/dfl_loss': 1.28184, 'fitness': 0.45693}
# Tuner: Best fitness model is runs/detect/train19
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune5/best_hyperparameters.yaml'
#
# lr0: 0.00951
# lrf: 0.01047
# momentum: 0.87164
# weight_decay: 0.0004
# warmup_epochs: 3.17432
# warmup_momentum: 0.79315
# box: 7.20983
# cls: 0.58434
# dfl: 1.17943
# hsv_h: 0.01901
# hsv_s: 0.81958
# hsv_v: 0.28226
# degrees: 0.0
# translate: 0.07462
# scale: 0.46414
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.4459
# bgr: 0.0
# mosaic: 0.63725
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 29/30 with hyperparameters: {'lr0': 0.00951, 'lrf': 0.01077, 'momentum': 0.86102, 'weight_decay': 0.00043, 'warmup_epochs': 3.11453, 'warmup_momentum': 0.87366, 'box': 7.64627, 'cls': 0.57055, 'dfl': 1.25212, 'hsv_h': 0.0206, 'hsv_s': 0.81958, 'hsv_v': 0.30472, 'degrees': 0.0, 'translate': 0.07462, 'scale': 0.48606, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.4459, 'bgr': 0.0, 'mosaic': 0.64766, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune5/tune_scatter_plots.png
# Saved runs/detect/tune5/tune_fitness.png
#
# Tuner: 29/30 iterations complete ✅ (10017.20s)
# Tuner: Results saved to runs/detect/tune5
# Tuner: Best fitness=0.45693 observed at iteration 15
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.76357, 'metrics/recall(B)': 0.61212, 'metrics/mAP50(B)': 0.7159, 'metrics/mAP50-95(B)': 0.42815, 'val/box_loss': 1.40391, 'val/cls_loss': 1.52279, 'val/dfl_loss': 1.28184, 'fitness': 0.45693}
# Tuner: Best fitness model is runs/detect/train19
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune5/best_hyperparameters.yaml'
#
# lr0: 0.00951
# lrf: 0.01047
# momentum: 0.87164
# weight_decay: 0.0004
# warmup_epochs: 3.17432
# warmup_momentum: 0.79315
# box: 7.20983
# cls: 0.58434
# dfl: 1.17943
# hsv_h: 0.01901
# hsv_s: 0.81958
# hsv_v: 0.28226
# degrees: 0.0
# translate: 0.07462
# scale: 0.46414
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.4459
# bgr: 0.0
# mosaic: 0.63725
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 30/30 with hyperparameters: {'lr0': 0.00735, 'lrf': 0.01056, 'momentum': 0.94024, 'weight_decay': 0.00041, 'warmup_epochs': 4.14394, 'warmup_momentum': 0.72648, 'box': 10.10661, 'cls': 0.72292, 'dfl': 1.21362, 'hsv_h': 0.01882, 'hsv_s': 0.81958, 'hsv_v': 0.35609, 'degrees': 0.0, 'translate': 0.07462, 'scale': 0.50169, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.58422, 'bgr': 0.0, 'mosaic': 0.67222, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune5/tune_scatter_plots.png
# Saved runs/detect/tune5/tune_fitness.png
#
# Tuner: 30/30 iterations complete ✅ (10361.27s)
# Tuner: Results saved to runs/detect/tune5
# Tuner: Best fitness=0.45693 observed at iteration 15
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.76357, 'metrics/recall(B)': 0.61212, 'metrics/mAP50(B)': 0.7159, 'metrics/mAP50-95(B)': 0.42815, 'val/box_loss': 1.40391, 'val/cls_loss': 1.52279, 'val/dfl_loss': 1.28184, 'fitness': 0.45693}
# Tuner: Best fitness model is runs/detect/train19
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune5/best_hyperparameters.yaml'
#
# lr0: 0.00951
# lrf: 0.01047
# momentum: 0.87164
# weight_decay: 0.0004
# warmup_epochs: 3.17432
# warmup_momentum: 0.79315
# box: 7.20983
# cls: 0.58434
# dfl: 1.17943
# hsv_h: 0.01901
# hsv_s: 0.81958
# hsv_v: 0.28226
# degrees: 0.0
# translate: 0.07462
# scale: 0.46414
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.4459
# bgr: 0.0
# mosaic: 0.63725
# mixup: 0.0
# copy_paste: 0.0
