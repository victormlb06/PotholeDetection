# %% [markdown]
# # Treino

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ROOT_DIR = '/content/drive/My Drive/DeepLearning-UFG/Projeto/Potholev2'

# %%
# !ls -la "/content/drive/My Drive/DeepLearning-UFG/Projeto/Potholev2"
# Out:
# total 39
# -rw------- 1 root root  372 Jun 21 11:23 best_hyperparameters.yaml
# -rw------- 1 root root  313 Apr 17 15:04 dataColab.yaml
# -rw------- 1 root root  280 Apr 17 15:02 data.yaml
# drwx------ 2 root root 4096 Jun 21 12:52 Modelos
# drwx------ 2 root root 4096 Jun 25 14:09 Modelos_HP_500
# drwx------ 2 root root 4096 Jun 26 12:10 Modelos_HP_500_V2
# drwx------ 2 root root 4096 Jun 22 10:40 Modelos_Sem_Hyper
# -rw------- 1 root root 1187 Apr 17 15:02 README.roboflow.txt
# drwx------ 2 root root 4096 Apr 29 14:54 runs
# drwx------ 2 root root 4096 Apr 17 15:05 test
# drwx------ 2 root root 4096 Apr 17 15:05 train
# drwx------ 2 root root 4096 Apr 17 15:05 valid
# drwx------ 2 root root 4096 Jun 27 12:27 YOLOv9t

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.2.45-py3-none-any.whl (793 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 793.6/793.6 kB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.25.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (3.7.1)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.8.0.76)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.11.4)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.3.0+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.18.0+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.66.4)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.0.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.13.1)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2024.6.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.15.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvjitlink_cu12-12.5.40-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 59.2 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, ultralytics-thop, ultralytics
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.40 nvidia-nvtx-cu12-12.1.105 ultralytics-8.2.45 ultralytics-thop-2.0.0

# %%
import os
import ultralytics
from ultralytics import YOLO

ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.45 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# Setup complete ✅ (12 CPUs, 83.5 GB RAM, 30.2/201.2 GB disk)

# %%
from ultralytics import YOLO

# Initialize the YOLO model
model = YOLO('yolov9c.yaml')

# Tune hyperparameters on COCO8 for 30 epochs
model.tune(data=os.path.join(ROOT_DIR,"dataColab.yaml"),
                  epochs=30, iterations=30,
                  optimizer='AdamW',
                  plots=True,
                  save=True,
                  val=True,
                  batch = -1,
                  device = 'cuda'
          )
# Out:
# Tuner: Initialized Tuner instance with 'tune_dir=runs/detect/tune'
# Tuner: 💡 Learn about tuning at https://docs.ultralytics.com/guides/hyperparameter-tuning
# Tuner: Starting iteration 1/30 with hyperparameters: {'lr0': 0.01, 'lrf': 0.01, 'momentum': 0.937, 'weight_decay': 0.0005, 'warmup_epochs': 3.0, 'warmup_momentum': 0.8, 'box': 7.5, 'cls': 0.5, 'dfl': 1.5, 'hsv_h': 0.015, 'hsv_s': 0.7, 'hsv_v': 0.4, 'degrees': 0.0, 'translate': 0.1, 'scale': 0.5, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.5, 'bgr': 0.0, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 1/30 iterations complete ✅ (654.42s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.36057 observed at iteration 1
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.72093, 'metrics/recall(B)': 0.48535, 'metrics/mAP50(B)': 0.58511, 'metrics/mAP50-95(B)': 0.33563, 'val/box_loss': 1.60713, 'val/cls_loss': 1.55862, 'val/dfl_loss': 1.63706, 'fitness': 0.36057}
# Tuner: Best fitness model is runs/detect/train
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.01
# momentum: 0.937
# weight_decay: 0.0005
# warmup_epochs: 3.0
# warmup_momentum: 0.8
# box: 7.5
# cls: 0.5
# dfl: 1.5
# hsv_h: 0.015
# hsv_s: 0.7
# hsv_v: 0.4
# degrees: 0.0
# translate: 0.1
# scale: 0.5
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.5
# bgr: 0.0
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 2/30 with hyperparameters: {'lr0': 0.01, 'lrf': 0.00968, 'momentum': 0.91152, 'weight_decay': 0.0005, 'warmup_epochs': 3.03149, 'warmup_momentum': 0.74639, 'box': 7.35667, 'cls': 0.43079, 'dfl': 1.64619, 'hsv_h': 0.01475, 'hsv_s': 0.7, 'hsv_v': 0.43809, 'degrees': 0.0, 'translate': 0.10159, 'scale': 0.5, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.5, 'bgr': 0.0, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 2/30 iterations complete ✅ (1262.26s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.36057 observed at iteration 1
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.72093, 'metrics/recall(B)': 0.48535, 'metrics/mAP50(B)': 0.58511, 'metrics/mAP50-95(B)': 0.33563, 'val/box_loss': 1.60713, 'val/cls_loss': 1.55862, 'val/dfl_loss': 1.63706, 'fitness': 0.36057}
# Tuner: Best fitness model is runs/detect/train
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.01
# momentum: 0.937
# weight_decay: 0.0005
# warmup_epochs: 3.0
# warmup_momentum: 0.8
# box: 7.5
# cls: 0.5
# dfl: 1.5
# hsv_h: 0.015
# hsv_s: 0.7
# hsv_v: 0.4
# degrees: 0.0
# translate: 0.1
# scale: 0.5
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.5
# bgr: 0.0
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 3/30 with hyperparameters: {'lr0': 0.0101, 'lrf': 0.01, 'momentum': 0.93646, 'weight_decay': 0.0005, 'warmup_epochs': 3.04467, 'warmup_momentum': 0.80143, 'box': 7.51662, 'cls': 0.49996, 'dfl': 1.497, 'hsv_h': 0.01506, 'hsv_s': 0.7008, 'hsv_v': 0.40419, 'degrees': 0.0, 'translate': 0.09877, 'scale': 0.5, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.50001, 'bgr': 0.0, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 3/30 iterations complete ✅ (1869.82s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.36057 observed at iteration 1
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.72093, 'metrics/recall(B)': 0.48535, 'metrics/mAP50(B)': 0.58511, 'metrics/mAP50-95(B)': 0.33563, 'val/box_loss': 1.60713, 'val/cls_loss': 1.55862, 'val/dfl_loss': 1.63706, 'fitness': 0.36057}
# Tuner: Best fitness model is runs/detect/train
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.01
# momentum: 0.937
# weight_decay: 0.0005
# warmup_epochs: 3.0
# warmup_momentum: 0.8
# box: 7.5
# cls: 0.5
# dfl: 1.5
# hsv_h: 0.015
# hsv_s: 0.7
# hsv_v: 0.4
# degrees: 0.0
# translate: 0.1
# scale: 0.5
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.5
# bgr: 0.0
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 4/30 with hyperparameters: {'lr0': 0.01, 'lrf': 0.00941, 'momentum': 0.91152, 'weight_decay': 0.0005, 'warmup_epochs': 3.03149, 'warmup_momentum': 0.73218, 'box': 7.35667, 'cls': 0.42603, 'dfl': 1.74779, 'hsv_h': 0.01475, 'hsv_s': 0.71464, 'hsv_v': 0.43558, 'degrees': 0.0, 'translate': 0.10159, 'scale': 0.5, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.48373, 'bgr': 0.0, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 4/30 iterations complete ✅ (2476.91s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.37253 observed at iteration 4
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.73062, 'metrics/recall(B)': 0.48788, 'metrics/mAP50(B)': 0.60503, 'metrics/mAP50-95(B)': 0.3467, 'val/box_loss': 1.56013, 'val/cls_loss': 1.28557, 'val/dfl_loss': 2.08497, 'fitness': 0.37253}
# Tuner: Best fitness model is runs/detect/train4
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.00941
# momentum: 0.91152
# weight_decay: 0.0005
# warmup_epochs: 3.03149
# warmup_momentum: 0.73218
# box: 7.35667
# cls: 0.42603
# dfl: 1.74779
# hsv_h: 0.01475
# hsv_s: 0.71464
# hsv_v: 0.43558
# degrees: 0.0
# translate: 0.10159
# scale: 0.5
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.48373
# bgr: 0.0
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 5/30 with hyperparameters: {'lr0': 0.00995, 'lrf': 0.00972, 'momentum': 0.89134, 'weight_decay': 0.0005, 'warmup_epochs': 3.06351, 'warmup_momentum': 0.75219, 'box': 7.71435, 'cls': 0.45393, 'dfl': 1.59637, 'hsv_h': 0.01502, 'hsv_s': 0.7, 'hsv_v': 0.4184, 'degrees': 0.0, 'translate': 0.10159, 'scale': 0.51727, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.50106, 'bgr': 0.0, 'mosaic': 0.98492, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 5/30 iterations complete ✅ (3087.45s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.37253 observed at iteration 4
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.73062, 'metrics/recall(B)': 0.48788, 'metrics/mAP50(B)': 0.60503, 'metrics/mAP50-95(B)': 0.3467, 'val/box_loss': 1.56013, 'val/cls_loss': 1.28557, 'val/dfl_loss': 2.08497, 'fitness': 0.37253}
# Tuner: Best fitness model is runs/detect/train4
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.00941
# momentum: 0.91152
# weight_decay: 0.0005
# warmup_epochs: 3.03149
# warmup_momentum: 0.73218
# box: 7.35667
# cls: 0.42603
# dfl: 1.74779
# hsv_h: 0.01475
# hsv_s: 0.71464
# hsv_v: 0.43558
# degrees: 0.0
# translate: 0.10159
# scale: 0.5
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.48373
# bgr: 0.0
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 6/30 with hyperparameters: {'lr0': 0.01059, 'lrf': 0.00968, 'momentum': 0.90513, 'weight_decay': 0.0005, 'warmup_epochs': 2.829, 'warmup_momentum': 0.88141, 'box': 7.35667, 'cls': 0.4339, 'dfl': 1.64619, 'hsv_h': 0.01391, 'hsv_s': 0.59891, 'hsv_v': 0.54583, 'degrees': 0.0, 'translate': 0.10159, 'scale': 0.37588, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.59478, 'bgr': 0.0, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 6/30 iterations complete ✅ (3697.79s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.37253 observed at iteration 4
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.73062, 'metrics/recall(B)': 0.48788, 'metrics/mAP50(B)': 0.60503, 'metrics/mAP50-95(B)': 0.3467, 'val/box_loss': 1.56013, 'val/cls_loss': 1.28557, 'val/dfl_loss': 2.08497, 'fitness': 0.37253}
# Tuner: Best fitness model is runs/detect/train4
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.00941
# momentum: 0.91152
# weight_decay: 0.0005
# warmup_epochs: 3.03149
# warmup_momentum: 0.73218
# box: 7.35667
# cls: 0.42603
# dfl: 1.74779
# hsv_h: 0.01475
# hsv_s: 0.71464
# hsv_v: 0.43558
# degrees: 0.0
# translate: 0.10159
# scale: 0.5
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.48373
# bgr: 0.0
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 7/30 with hyperparameters: {'lr0': 0.01099, 'lrf': 0.00968, 'momentum': 0.92567, 'weight_decay': 0.00046, 'warmup_epochs': 2.5266, 'warmup_momentum': 0.83732, 'box': 7.04943, 'cls': 0.48453, 'dfl': 1.32209, 'hsv_h': 0.01726, 'hsv_s': 0.74213, 'hsv_v': 0.43809, 'degrees': 0.0, 'translate': 0.09436, 'scale': 0.56893, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.51871, 'bgr': 0.0, 'mosaic': 0.87688, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 7/30 iterations complete ✅ (4304.43s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.37253 observed at iteration 4
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.73062, 'metrics/recall(B)': 0.48788, 'metrics/mAP50(B)': 0.60503, 'metrics/mAP50-95(B)': 0.3467, 'val/box_loss': 1.56013, 'val/cls_loss': 1.28557, 'val/dfl_loss': 2.08497, 'fitness': 0.37253}
# Tuner: Best fitness model is runs/detect/train4
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.00941
# momentum: 0.91152
# weight_decay: 0.0005
# warmup_epochs: 3.03149
# warmup_momentum: 0.73218
# box: 7.35667
# cls: 0.42603
# dfl: 1.74779
# hsv_h: 0.01475
# hsv_s: 0.71464
# hsv_v: 0.43558
# degrees: 0.0
# translate: 0.10159
# scale: 0.5
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.48373
# bgr: 0.0
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 8/30 with hyperparameters: {'lr0': 0.00893, 'lrf': 0.01028, 'momentum': 0.87771, 'weight_decay': 0.00048, 'warmup_epochs': 3.35445, 'warmup_momentum': 0.75314, 'box': 10.31779, 'cls': 0.47963, 'dfl': 1.2831, 'hsv_h': 0.01079, 'hsv_s': 0.78324, 'hsv_v': 0.25598, 'degrees': 0.0, 'translate': 0.1, 'scale': 0.45211, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.56302, 'bgr': 0.0, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 8/30 iterations complete ✅ (4914.03s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.39908 observed at iteration 8
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.7305, 'metrics/recall(B)': 0.57879, 'metrics/mAP50(B)': 0.64873, 'metrics/mAP50-95(B)': 0.37134, 'val/box_loss': 2.11234, 'val/cls_loss': 1.36353, 'val/dfl_loss': 1.44873, 'fitness': 0.39908}
# Tuner: Best fitness model is runs/detect/train8
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.00893
# lrf: 0.01028
# momentum: 0.87771
# weight_decay: 0.00048
# warmup_epochs: 3.35445
# warmup_momentum: 0.75314
# box: 10.31779
# cls: 0.47963
# dfl: 1.2831
# hsv_h: 0.01079
# hsv_s: 0.78324
# hsv_v: 0.25598
# degrees: 0.0
# translate: 0.1
# scale: 0.45211
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.56302
# bgr: 0.0
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 9/30 with hyperparameters: {'lr0': 0.00978, 'lrf': 0.00904, 'momentum': 0.90285, 'weight_decay': 0.00048, 'warmup_epochs': 2.92831, 'warmup_momentum': 0.74065, 'box': 7.35667, 'cls': 0.42603, 'dfl': 1.74446, 'hsv_h': 0.01475, 'hsv_s': 0.71464, 'hsv_v': 0.44265, 'degrees': 0.0, 'translate': 0.10303, 'scale': 0.50575, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.48373, 'bgr': 0.0, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 9/30 iterations complete ✅ (5520.18s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.39908 observed at iteration 8
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.7305, 'metrics/recall(B)': 0.57879, 'metrics/mAP50(B)': 0.64873, 'metrics/mAP50-95(B)': 0.37134, 'val/box_loss': 2.11234, 'val/cls_loss': 1.36353, 'val/dfl_loss': 1.44873, 'fitness': 0.39908}
# Tuner: Best fitness model is runs/detect/train8
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.00893
# lrf: 0.01028
# momentum: 0.87771
# weight_decay: 0.00048
# warmup_epochs: 3.35445
# warmup_momentum: 0.75314
# box: 10.31779
# cls: 0.47963
# dfl: 1.2831
# hsv_h: 0.01079
# hsv_s: 0.78324
# hsv_v: 0.25598
# degrees: 0.0
# translate: 0.1
# scale: 0.45211
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.56302
# bgr: 0.0
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 10/30 with hyperparameters: {'lr0': 0.00908, 'lrf': 0.00886, 'momentum': 0.91115, 'weight_decay': 0.00063, 'warmup_epochs': 3.41339, 'warmup_momentum': 0.79777, 'box': 7.35667, 'cls': 0.4437, 'dfl': 1.41215, 'hsv_h': 0.01475, 'hsv_s': 0.70444, 'hsv_v': 0.3583, 'degrees': 0.0, 'translate': 0.09136, 'scale': 0.48675, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.48373, 'bgr': 0.0, 'mosaic': 0.87263, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 10/30 iterations complete ✅ (6129.75s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.39908 observed at iteration 8
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.7305, 'metrics/recall(B)': 0.57879, 'metrics/mAP50(B)': 0.64873, 'metrics/mAP50-95(B)': 0.37134, 'val/box_loss': 2.11234, 'val/cls_loss': 1.36353, 'val/dfl_loss': 1.44873, 'fitness': 0.39908}
# Tuner: Best fitness model is runs/detect/train8
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.00893
# lrf: 0.01028
# momentum: 0.87771
# weight_decay: 0.00048
# warmup_epochs: 3.35445
# warmup_momentum: 0.75314
# box: 10.31779
# cls: 0.47963
# dfl: 1.2831
# hsv_h: 0.01079
# hsv_s: 0.78324
# hsv_v: 0.25598
# degrees: 0.0
# translate: 0.1
# scale: 0.45211
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.56302
# bgr: 0.0
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 11/30 with hyperparameters: {'lr0': 0.00893, 'lrf': 0.01059, 'momentum': 0.88258, 'weight_decay': 0.00043, 'warmup_epochs': 3.06653, 'warmup_momentum': 0.71652, 'box': 8.83456, 'cls': 0.46944, 'dfl': 1.21905, 'hsv_h': 0.01127, 'hsv_s': 0.77507, 'hsv_v': 0.24906, 'degrees': 0.0, 'translate': 0.10291, 'scale': 0.46438, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.56302, 'bgr': 0.0, 'mosaic': 0.92355, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 11/30 iterations complete ✅ (6737.23s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.39908 observed at iteration 8
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.7305, 'metrics/recall(B)': 0.57879, 'metrics/mAP50(B)': 0.64873, 'metrics/mAP50-95(B)': 0.37134, 'val/box_loss': 2.11234, 'val/cls_loss': 1.36353, 'val/dfl_loss': 1.44873, 'fitness': 0.39908}
# Tuner: Best fitness model is runs/detect/train8
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.00893
# lrf: 0.01028
# momentum: 0.87771
# weight_decay: 0.00048
# warmup_epochs: 3.35445
# warmup_momentum: 0.75314
# box: 10.31779
# cls: 0.47963
# dfl: 1.2831
# hsv_h: 0.01079
# hsv_s: 0.78324
# hsv_v: 0.25598
# degrees: 0.0
# translate: 0.1
# scale: 0.45211
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.56302
# bgr: 0.0
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 12/30 with hyperparameters: {'lr0': 0.00893, 'lrf': 0.00876, 'momentum': 0.90598, 'weight_decay': 0.00063, 'warmup_epochs': 3.39852, 'warmup_momentum': 0.79777, 'box': 7.36876, 'cls': 0.43869, 'dfl': 1.42337, 'hsv_h': 0.01521, 'hsv_s': 0.73397, 'hsv_v': 0.36507, 'degrees': 0.0, 'translate': 0.09136, 'scale': 0.49466, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.48841, 'bgr': 0.0, 'mosaic': 0.89553, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 12/30 iterations complete ✅ (7345.31s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.39908 observed at iteration 8
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.7305, 'metrics/recall(B)': 0.57879, 'metrics/mAP50(B)': 0.64873, 'metrics/mAP50-95(B)': 0.37134, 'val/box_loss': 2.11234, 'val/cls_loss': 1.36353, 'val/dfl_loss': 1.44873, 'fitness': 0.39908}
# Tuner: Best fitness model is runs/detect/train8
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.00893
# lrf: 0.01028
# momentum: 0.87771
# weight_decay: 0.00048
# warmup_epochs: 3.35445
# warmup_momentum: 0.75314
# box: 10.31779
# cls: 0.47963
# dfl: 1.2831
# hsv_h: 0.01079
# hsv_s: 0.78324
# hsv_v: 0.25598
# degrees: 0.0
# translate: 0.1
# scale: 0.45211
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.56302
# bgr: 0.0
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 13/30 with hyperparameters: {'lr0': 0.01027, 'lrf': 0.01028, 'momentum': 0.90513, 'weight_decay': 0.00048, 'warmup_epochs': 3.7367, 'warmup_momentum': 0.89644, 'box': 10.15421, 'cls': 0.48576, 'dfl': 1.37284, 'hsv_h': 0.00983, 'hsv_s': 0.81597, 'hsv_v': 0.25598, 'degrees': 0.0, 'translate': 0.10673, 'scale': 0.43417, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.53664, 'bgr': 0.0, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 13/30 iterations complete ✅ (7953.54s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.39908 observed at iteration 8
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.7305, 'metrics/recall(B)': 0.57879, 'metrics/mAP50(B)': 0.64873, 'metrics/mAP50-95(B)': 0.37134, 'val/box_loss': 2.11234, 'val/cls_loss': 1.36353, 'val/dfl_loss': 1.44873, 'fitness': 0.39908}
# Tuner: Best fitness model is runs/detect/train8
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.00893
# lrf: 0.01028
# momentum: 0.87771
# weight_decay: 0.00048
# warmup_epochs: 3.35445
# warmup_momentum: 0.75314
# box: 10.31779
# cls: 0.47963
# dfl: 1.2831
# hsv_h: 0.01079
# hsv_s: 0.78324
# hsv_v: 0.25598
# degrees: 0.0
# translate: 0.1
# scale: 0.45211
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.56302
# bgr: 0.0
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 14/30 with hyperparameters: {'lr0': 0.00615, 'lrf': 0.00947, 'momentum': 0.85453, 'weight_decay': 0.00048, 'warmup_epochs': 3.62176, 'warmup_momentum': 0.57398, 'box': 10.31779, 'cls': 0.47963, 'dfl': 1.39018, 'hsv_h': 0.01146, 'hsv_s': 0.79074, 'hsv_v': 0.22225, 'degrees': 0.0, 'translate': 0.1, 'scale': 0.45211, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.56302, 'bgr': 0.0, 'mosaic': 0.94995, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 14/30 iterations complete ✅ (8562.17s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.40654 observed at iteration 14
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.69421, 'metrics/recall(B)': 0.56061, 'metrics/mAP50(B)': 0.65218, 'metrics/mAP50-95(B)': 0.37925, 'val/box_loss': 2.09922, 'val/cls_loss': 1.32636, 'val/dfl_loss': 1.5184, 'fitness': 0.40654}
# Tuner: Best fitness model is runs/detect/train14
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.00615
# lrf: 0.00947
# momentum: 0.85453
# weight_decay: 0.00048
# warmup_epochs: 3.62176
# warmup_momentum: 0.57398
# box: 10.31779
# cls: 0.47963
# dfl: 1.39018
# hsv_h: 0.01146
# hsv_s: 0.79074
# hsv_v: 0.22225
# degrees: 0.0
# translate: 0.1
# scale: 0.45211
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.56302
# bgr: 0.0
# mosaic: 0.94995
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 15/30 with hyperparameters: {'lr0': 0.00615, 'lrf': 0.01064, 'momentum': 0.84288, 'weight_decay': 0.00042, 'warmup_epochs': 3.62176, 'warmup_momentum': 0.57398, 'box': 7.76704, 'cls': 0.4514, 'dfl': 1.22922, 'hsv_h': 0.00999, 'hsv_s': 0.82094, 'hsv_v': 0.22225, 'degrees': 0.0, 'translate': 0.10053, 'scale': 0.44463, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.49649, 'bgr': 0.0, 'mosaic': 0.94995, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 15/30 iterations complete ✅ (9168.00s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.40654 observed at iteration 14
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.69421, 'metrics/recall(B)': 0.56061, 'metrics/mAP50(B)': 0.65218, 'metrics/mAP50-95(B)': 0.37925, 'val/box_loss': 2.09922, 'val/cls_loss': 1.32636, 'val/dfl_loss': 1.5184, 'fitness': 0.40654}
# Tuner: Best fitness model is runs/detect/train14
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.00615
# lrf: 0.00947
# momentum: 0.85453
# weight_decay: 0.00048
# warmup_epochs: 3.62176
# warmup_momentum: 0.57398
# box: 10.31779
# cls: 0.47963
# dfl: 1.39018
# hsv_h: 0.01146
# hsv_s: 0.79074
# hsv_v: 0.22225
# degrees: 0.0
# translate: 0.1
# scale: 0.45211
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.56302
# bgr: 0.0
# mosaic: 0.94995
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 16/30 with hyperparameters: {'lr0': 0.00666, 'lrf': 0.0101, 'momentum': 0.83642, 'weight_decay': 0.00042, 'warmup_epochs': 3.50922, 'warmup_momentum': 0.57398, 'box': 7.39268, 'cls': 0.44558, 'dfl': 1.24993, 'hsv_h': 0.00962, 'hsv_s': 0.82094, 'hsv_v': 0.20983, 'degrees': 0.0, 'translate': 0.10064, 'scale': 0.38394, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.53569, 'bgr': 0.0, 'mosaic': 0.95291, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 16/30 iterations complete ✅ (9774.54s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.40654 observed at iteration 14
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.69421, 'metrics/recall(B)': 0.56061, 'metrics/mAP50(B)': 0.65218, 'metrics/mAP50-95(B)': 0.37925, 'val/box_loss': 2.09922, 'val/cls_loss': 1.32636, 'val/dfl_loss': 1.5184, 'fitness': 0.40654}
# Tuner: Best fitness model is runs/detect/train14
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.00615
# lrf: 0.00947
# momentum: 0.85453
# weight_decay: 0.00048
# warmup_epochs: 3.62176
# warmup_momentum: 0.57398
# box: 10.31779
# cls: 0.47963
# dfl: 1.39018
# hsv_h: 0.01146
# hsv_s: 0.79074
# hsv_v: 0.22225
# degrees: 0.0
# translate: 0.1
# scale: 0.45211
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.56302
# bgr: 0.0
# mosaic: 0.94995
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 17/30 with hyperparameters: {'lr0': 0.00615, 'lrf': 0.00883, 'momentum': 0.87247, 'weight_decay': 0.00038, 'warmup_epochs': 3.62176, 'warmup_momentum': 0.70232, 'box': 8.71162, 'cls': 0.47963, 'dfl': 1.43735, 'hsv_h': 0.01006, 'hsv_s': 0.9, 'hsv_v': 0.2427, 'degrees': 0.0, 'translate': 0.08667, 'scale': 0.49483, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.56302, 'bgr': 0.0, 'mosaic': 0.64524, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 17/30 iterations complete ✅ (10382.54s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.4097 observed at iteration 17
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.70647, 'metrics/recall(B)': 0.58485, 'metrics/mAP50(B)': 0.66194, 'metrics/mAP50-95(B)': 0.38167, 'val/box_loss': 1.73544, 'val/cls_loss': 1.30711, 'val/dfl_loss': 1.57163, 'fitness': 0.4097}
# Tuner: Best fitness model is runs/detect/train17
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.00615
# lrf: 0.00883
# momentum: 0.87247
# weight_decay: 0.00038
# warmup_epochs: 3.62176
# warmup_momentum: 0.70232
# box: 8.71162
# cls: 0.47963
# dfl: 1.43735
# hsv_h: 0.01006
# hsv_s: 0.9
# hsv_v: 0.2427
# degrees: 0.0
# translate: 0.08667
# scale: 0.49483
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.56302
# bgr: 0.0
# mosaic: 0.64524
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 18/30 with hyperparameters: {'lr0': 0.00615, 'lrf': 0.01012, 'momentum': 0.83295, 'weight_decay': 0.00046, 'warmup_epochs': 3.8236, 'warmup_momentum': 0.55637, 'box': 9.71683, 'cls': 0.45009, 'dfl': 1.44024, 'hsv_h': 0.01113, 'hsv_s': 0.83495, 'hsv_v': 0.24533, 'degrees': 0.0, 'translate': 0.099, 'scale': 0.42493, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.58208, 'bgr': 0.0, 'mosaic': 0.96338, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 18/30 iterations complete ✅ (10989.75s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.42682 observed at iteration 18
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.75456, 'metrics/recall(B)': 0.5697, 'metrics/mAP50(B)': 0.6713, 'metrics/mAP50-95(B)': 0.39966, 'val/box_loss': 1.98975, 'val/cls_loss': 1.19799, 'val/dfl_loss': 1.4941, 'fitness': 0.42682}
# Tuner: Best fitness model is runs/detect/train18
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.00615
# lrf: 0.01012
# momentum: 0.83295
# weight_decay: 0.00046
# warmup_epochs: 3.8236
# warmup_momentum: 0.55637
# box: 9.71683
# cls: 0.45009
# dfl: 1.44024
# hsv_h: 0.01113
# hsv_s: 0.83495
# hsv_v: 0.24533
# degrees: 0.0
# translate: 0.099
# scale: 0.42493
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.58208
# bgr: 0.0
# mosaic: 0.96338
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 19/30 with hyperparameters: {'lr0': 0.00557, 'lrf': 0.0103, 'momentum': 0.8074, 'weight_decay': 0.00046, 'warmup_epochs': 3.8236, 'warmup_momentum': 0.49742, 'box': 9.71683, 'cls': 0.42973, 'dfl': 1.33114, 'hsv_h': 0.0116, 'hsv_s': 0.70587, 'hsv_v': 0.24702, 'degrees': 0.0, 'translate': 0.099, 'scale': 0.42493, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.6258, 'bgr': 0.0, 'mosaic': 0.85528, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 19/30 iterations complete ✅ (11597.57s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.42682 observed at iteration 18
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.75456, 'metrics/recall(B)': 0.5697, 'metrics/mAP50(B)': 0.6713, 'metrics/mAP50-95(B)': 0.39966, 'val/box_loss': 1.98975, 'val/cls_loss': 1.19799, 'val/dfl_loss': 1.4941, 'fitness': 0.42682}
# Tuner: Best fitness model is runs/detect/train18
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.00615
# lrf: 0.01012
# momentum: 0.83295
# weight_decay: 0.00046
# warmup_epochs: 3.8236
# warmup_momentum: 0.55637
# box: 9.71683
# cls: 0.45009
# dfl: 1.44024
# hsv_h: 0.01113
# hsv_s: 0.83495
# hsv_v: 0.24533
# degrees: 0.0
# translate: 0.099
# scale: 0.42493
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.58208
# bgr: 0.0
# mosaic: 0.96338
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 20/30 with hyperparameters: {'lr0': 0.0058, 'lrf': 0.01066, 'momentum': 0.76812, 'weight_decay': 0.00046, 'warmup_epochs': 3.62176, 'warmup_momentum': 0.61304, 'box': 10.31779, 'cls': 0.68449, 'dfl': 1.43229, 'hsv_h': 0.01146, 'hsv_s': 0.57653, 'hsv_v': 0.1699, 'degrees': 0.0, 'translate': 0.1, 'scale': 0.55122, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.66226, 'bgr': 0.0, 'mosaic': 0.91063, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 20/30 iterations complete ✅ (12202.93s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.42682 observed at iteration 18
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.75456, 'metrics/recall(B)': 0.5697, 'metrics/mAP50(B)': 0.6713, 'metrics/mAP50-95(B)': 0.39966, 'val/box_loss': 1.98975, 'val/cls_loss': 1.19799, 'val/dfl_loss': 1.4941, 'fitness': 0.42682}
# Tuner: Best fitness model is runs/detect/train18
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.00615
# lrf: 0.01012
# momentum: 0.83295
# weight_decay: 0.00046
# warmup_epochs: 3.8236
# warmup_momentum: 0.55637
# box: 9.71683
# cls: 0.45009
# dfl: 1.44024
# hsv_h: 0.01113
# hsv_s: 0.83495
# hsv_v: 0.24533
# degrees: 0.0
# translate: 0.099
# scale: 0.42493
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.58208
# bgr: 0.0
# mosaic: 0.96338
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 21/30 with hyperparameters: {'lr0': 0.00578, 'lrf': 0.01066, 'momentum': 0.76892, 'weight_decay': 0.00046, 'warmup_epochs': 3.62176, 'warmup_momentum': 0.61304, 'box': 10.31779, 'cls': 0.68449, 'dfl': 1.42908, 'hsv_h': 0.01146, 'hsv_s': 0.57403, 'hsv_v': 0.1706, 'degrees': 0.0, 'translate': 0.09999, 'scale': 0.55122, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.66156, 'bgr': 0.0, 'mosaic': 0.91429, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 21/30 iterations complete ✅ (12806.87s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.42682 observed at iteration 18
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.75456, 'metrics/recall(B)': 0.5697, 'metrics/mAP50(B)': 0.6713, 'metrics/mAP50-95(B)': 0.39966, 'val/box_loss': 1.98975, 'val/cls_loss': 1.19799, 'val/dfl_loss': 1.4941, 'fitness': 0.42682}
# Tuner: Best fitness model is runs/detect/train18
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.00615
# lrf: 0.01012
# momentum: 0.83295
# weight_decay: 0.00046
# warmup_epochs: 3.8236
# warmup_momentum: 0.55637
# box: 9.71683
# cls: 0.45009
# dfl: 1.44024
# hsv_h: 0.01113
# hsv_s: 0.83495
# hsv_v: 0.24533
# degrees: 0.0
# translate: 0.099
# scale: 0.42493
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.58208
# bgr: 0.0
# mosaic: 0.96338
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 22/30 with hyperparameters: {'lr0': 0.00658, 'lrf': 0.00949, 'momentum': 0.83295, 'weight_decay': 0.00047, 'warmup_epochs': 3.75654, 'warmup_momentum': 0.55637, 'box': 9.77683, 'cls': 0.44524, 'dfl': 1.45359, 'hsv_h': 0.01097, 'hsv_s': 0.83495, 'hsv_v': 0.24168, 'degrees': 0.0, 'translate': 0.10158, 'scale': 0.41126, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.58208, 'bgr': 0.0, 'mosaic': 0.92358, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 22/30 iterations complete ✅ (13413.31s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.42682 observed at iteration 18
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.75456, 'metrics/recall(B)': 0.5697, 'metrics/mAP50(B)': 0.6713, 'metrics/mAP50-95(B)': 0.39966, 'val/box_loss': 1.98975, 'val/cls_loss': 1.19799, 'val/dfl_loss': 1.4941, 'fitness': 0.42682}
# Tuner: Best fitness model is runs/detect/train18
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.00615
# lrf: 0.01012
# momentum: 0.83295
# weight_decay: 0.00046
# warmup_epochs: 3.8236
# warmup_momentum: 0.55637
# box: 9.71683
# cls: 0.45009
# dfl: 1.44024
# hsv_h: 0.01113
# hsv_s: 0.83495
# hsv_v: 0.24533
# degrees: 0.0
# translate: 0.099
# scale: 0.42493
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.58208
# bgr: 0.0
# mosaic: 0.96338
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 23/30 with hyperparameters: {'lr0': 0.00628, 'lrf': 0.00883, 'momentum': 0.87278, 'weight_decay': 0.00039, 'warmup_epochs': 3.61606, 'warmup_momentum': 0.69703, 'box': 8.71576, 'cls': 0.47573, 'dfl': 1.42367, 'hsv_h': 0.00994, 'hsv_s': 0.9, 'hsv_v': 0.2427, 'degrees': 0.0, 'translate': 0.08667, 'scale': 0.48808, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.5611, 'bgr': 0.0, 'mosaic': 0.64871, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 23/30 iterations complete ✅ (14021.03s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.42682 observed at iteration 18
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.75456, 'metrics/recall(B)': 0.5697, 'metrics/mAP50(B)': 0.6713, 'metrics/mAP50-95(B)': 0.39966, 'val/box_loss': 1.98975, 'val/cls_loss': 1.19799, 'val/dfl_loss': 1.4941, 'fitness': 0.42682}
# Tuner: Best fitness model is runs/detect/train18
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.00615
# lrf: 0.01012
# momentum: 0.83295
# weight_decay: 0.00046
# warmup_epochs: 3.8236
# warmup_momentum: 0.55637
# box: 9.71683
# cls: 0.45009
# dfl: 1.44024
# hsv_h: 0.01113
# hsv_s: 0.83495
# hsv_v: 0.24533
# degrees: 0.0
# translate: 0.099
# scale: 0.42493
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.58208
# bgr: 0.0
# mosaic: 0.96338
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 24/30 with hyperparameters: {'lr0': 0.00582, 'lrf': 0.01086, 'momentum': 0.76812, 'weight_decay': 0.00046, 'warmup_epochs': 3.63366, 'warmup_momentum': 0.61304, 'box': 10.31779, 'cls': 0.68287, 'dfl': 1.45651, 'hsv_h': 0.0113, 'hsv_s': 0.57168, 'hsv_v': 0.1699, 'degrees': 0.0, 'translate': 0.09892, 'scale': 0.5656, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.67084, 'bgr': 0.0, 'mosaic': 0.91024, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 24/30 iterations complete ✅ (14628.70s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.44123 observed at iteration 24
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.71469, 'metrics/recall(B)': 0.59968, 'metrics/mAP50(B)': 0.69916, 'metrics/mAP50-95(B)': 0.41257, 'val/box_loss': 2.06157, 'val/cls_loss': 1.86419, 'val/dfl_loss': 1.599, 'fitness': 0.44123}
# Tuner: Best fitness model is runs/detect/train24
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.00582
# lrf: 0.01086
# momentum: 0.76812
# weight_decay: 0.00046
# warmup_epochs: 3.63366
# warmup_momentum: 0.61304
# box: 10.31779
# cls: 0.68287
# dfl: 1.45651
# hsv_h: 0.0113
# hsv_s: 0.57168
# hsv_v: 0.1699
# degrees: 0.0
# translate: 0.09892
# scale: 0.5656
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.67084
# bgr: 0.0
# mosaic: 0.91024
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 25/30 with hyperparameters: {'lr0': 0.00482, 'lrf': 0.0114, 'momentum': 0.78982, 'weight_decay': 0.00042, 'warmup_epochs': 3.59209, 'warmup_momentum': 0.6094, 'box': 10.31779, 'cls': 0.55154, 'dfl': 1.34991, 'hsv_h': 0.0101, 'hsv_s': 0.55068, 'hsv_v': 0.16472, 'degrees': 0.0, 'translate': 0.09892, 'scale': 0.63686, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.67878, 'bgr': 0.0, 'mosaic': 0.91024, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 25/30 iterations complete ✅ (15237.57s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.44123 observed at iteration 24
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.71469, 'metrics/recall(B)': 0.59968, 'metrics/mAP50(B)': 0.69916, 'metrics/mAP50-95(B)': 0.41257, 'val/box_loss': 2.06157, 'val/cls_loss': 1.86419, 'val/dfl_loss': 1.599, 'fitness': 0.44123}
# Tuner: Best fitness model is runs/detect/train24
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.00582
# lrf: 0.01086
# momentum: 0.76812
# weight_decay: 0.00046
# warmup_epochs: 3.63366
# warmup_momentum: 0.61304
# box: 10.31779
# cls: 0.68287
# dfl: 1.45651
# hsv_h: 0.0113
# hsv_s: 0.57168
# hsv_v: 0.1699
# degrees: 0.0
# translate: 0.09892
# scale: 0.5656
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.67084
# bgr: 0.0
# mosaic: 0.91024
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 26/30 with hyperparameters: {'lr0': 0.00616, 'lrf': 0.00885, 'momentum': 0.76812, 'weight_decay': 0.00046, 'warmup_epochs': 2.30064, 'warmup_momentum': 0.35393, 'box': 8.68325, 'cls': 0.63058, 'dfl': 0.95233, 'hsv_h': 0.00909, 'hsv_s': 0.57168, 'hsv_v': 0.18261, 'degrees': 0.0, 'translate': 0.08549, 'scale': 0.48572, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.6423, 'bgr': 0.0, 'mosaic': 0.91024, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 26/30 iterations complete ✅ (15842.99s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.44123 observed at iteration 24
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.71469, 'metrics/recall(B)': 0.59968, 'metrics/mAP50(B)': 0.69916, 'metrics/mAP50-95(B)': 0.41257, 'val/box_loss': 2.06157, 'val/cls_loss': 1.86419, 'val/dfl_loss': 1.599, 'fitness': 0.44123}
# Tuner: Best fitness model is runs/detect/train24
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.00582
# lrf: 0.01086
# momentum: 0.76812
# weight_decay: 0.00046
# warmup_epochs: 3.63366
# warmup_momentum: 0.61304
# box: 10.31779
# cls: 0.68287
# dfl: 1.45651
# hsv_h: 0.0113
# hsv_s: 0.57168
# hsv_v: 0.1699
# degrees: 0.0
# translate: 0.09892
# scale: 0.5656
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.67084
# bgr: 0.0
# mosaic: 0.91024
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 27/30 with hyperparameters: {'lr0': 0.00556, 'lrf': 0.0101, 'momentum': 0.77493, 'weight_decay': 0.00039, 'warmup_epochs': 3.56261, 'warmup_momentum': 0.58188, 'box': 11.65841, 'cls': 0.63421, 'dfl': 1.45651, 'hsv_h': 0.01242, 'hsv_s': 0.58419, 'hsv_v': 0.16409, 'degrees': 0.0, 'translate': 0.09264, 'scale': 0.53984, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.62852, 'bgr': 0.0, 'mosaic': 0.89524, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 27/30 iterations complete ✅ (16447.64s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.44123 observed at iteration 24
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.71469, 'metrics/recall(B)': 0.59968, 'metrics/mAP50(B)': 0.69916, 'metrics/mAP50-95(B)': 0.41257, 'val/box_loss': 2.06157, 'val/cls_loss': 1.86419, 'val/dfl_loss': 1.599, 'fitness': 0.44123}
# Tuner: Best fitness model is runs/detect/train24
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.00582
# lrf: 0.01086
# momentum: 0.76812
# weight_decay: 0.00046
# warmup_epochs: 3.63366
# warmup_momentum: 0.61304
# box: 10.31779
# cls: 0.68287
# dfl: 1.45651
# hsv_h: 0.0113
# hsv_s: 0.57168
# hsv_v: 0.1699
# degrees: 0.0
# translate: 0.09892
# scale: 0.5656
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.67084
# bgr: 0.0
# mosaic: 0.91024
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 28/30 with hyperparameters: {'lr0': 0.0054, 'lrf': 0.01086, 'momentum': 0.76483, 'weight_decay': 0.0005, 'warmup_epochs': 3.63366, 'warmup_momentum': 0.56728, 'box': 9.46188, 'cls': 0.78898, 'dfl': 1.24567, 'hsv_h': 0.0111, 'hsv_s': 0.61757, 'hsv_v': 0.16703, 'degrees': 0.0, 'translate': 0.1099, 'scale': 0.60365, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.62764, 'bgr': 0.0, 'mosaic': 0.93408, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 28/30 iterations complete ✅ (17054.29s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.44123 observed at iteration 24
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.71469, 'metrics/recall(B)': 0.59968, 'metrics/mAP50(B)': 0.69916, 'metrics/mAP50-95(B)': 0.41257, 'val/box_loss': 2.06157, 'val/cls_loss': 1.86419, 'val/dfl_loss': 1.599, 'fitness': 0.44123}
# Tuner: Best fitness model is runs/detect/train24
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.00582
# lrf: 0.01086
# momentum: 0.76812
# weight_decay: 0.00046
# warmup_epochs: 3.63366
# warmup_momentum: 0.61304
# box: 10.31779
# cls: 0.68287
# dfl: 1.45651
# hsv_h: 0.0113
# hsv_s: 0.57168
# hsv_v: 0.1699
# degrees: 0.0
# translate: 0.09892
# scale: 0.5656
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.67084
# bgr: 0.0
# mosaic: 0.91024
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 29/30 with hyperparameters: {'lr0': 0.00545, 'lrf': 0.00719, 'momentum': 0.72447, 'weight_decay': 0.00031, 'warmup_epochs': 3.63366, 'warmup_momentum': 0.61304, 'box': 13.0384, 'cls': 0.68287, 'dfl': 1.26264, 'hsv_h': 0.01547, 'hsv_s': 0.77319, 'hsv_v': 0.14951, 'degrees': 0.0, 'translate': 0.09892, 'scale': 0.61128, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.55413, 'bgr': 0.0, 'mosaic': 0.63018, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 29/30 iterations complete ✅ (17659.21s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.44123 observed at iteration 24
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.71469, 'metrics/recall(B)': 0.59968, 'metrics/mAP50(B)': 0.69916, 'metrics/mAP50-95(B)': 0.41257, 'val/box_loss': 2.06157, 'val/cls_loss': 1.86419, 'val/dfl_loss': 1.599, 'fitness': 0.44123}
# Tuner: Best fitness model is runs/detect/train24
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.00582
# lrf: 0.01086
# momentum: 0.76812
# weight_decay: 0.00046
# warmup_epochs: 3.63366
# warmup_momentum: 0.61304
# box: 10.31779
# cls: 0.68287
# dfl: 1.45651
# hsv_h: 0.0113
# hsv_s: 0.57168
# hsv_v: 0.1699
# degrees: 0.0
# translate: 0.09892
# scale: 0.5656
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.67084
# bgr: 0.0
# mosaic: 0.91024
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 30/30 with hyperparameters: {'lr0': 0.00482, 'lrf': 0.0114, 'momentum': 0.79709, 'weight_decay': 0.00037, 'warmup_epochs': 3.3261, 'warmup_momentum': 0.6776, 'box': 10.11703, 'cls': 0.55154, 'dfl': 1.34991, 'hsv_h': 0.0116, 'hsv_s': 0.61991, 'hsv_v': 0.1659, 'degrees': 0.0, 'translate': 0.10933, 'scale': 0.68043, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.74484, 'bgr': 0.0, 'mosaic': 0.89876, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 30/30 iterations complete ✅ (18267.48s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.44123 observed at iteration 24
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.71469, 'metrics/recall(B)': 0.59968, 'metrics/mAP50(B)': 0.69916, 'metrics/mAP50-95(B)': 0.41257, 'val/box_loss': 2.06157, 'val/cls_loss': 1.86419, 'val/dfl_loss': 1.599, 'fitness': 0.44123}
# Tuner: Best fitness model is runs/detect/train24
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.00582
# lrf: 0.01086
# momentum: 0.76812
# weight_decay: 0.00046
# warmup_epochs: 3.63366
# warmup_momentum: 0.61304
# box: 10.31779
# cls: 0.68287
# dfl: 1.45651
# hsv_h: 0.0113
# hsv_s: 0.57168
# hsv_v: 0.1699
# degrees: 0.0
# translate: 0.09892
# scale: 0.5656
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.67084
# bgr: 0.0
# mosaic: 0.91024
# mixup: 0.0
# copy_paste: 0.0
